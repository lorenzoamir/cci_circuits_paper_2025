# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import os
import numpy as np
import scanpy as sc
import PyWGCNA
import seaborn as sns
from sklearn.metrics import roc_curve, roc_auc_score
from scipy.stats import mannwhitneyu, false_discovery_control
import re
from itertools import combinations
from scipy.stats import pearsonr
import ast

# %%
def stack_triangle(df, col):
    df = pd.DataFrame(
        df.where(
            np.tri(
                df.shape[0],
                dtype=bool,
                k=-1
            ),
            np.nan
        ).stack(dropna=True), columns=[col] 
    )
    
    return df

# %%
# Function that generates and saves the ROC curve
def generate_roc_curve(
    data,
    target_col,
    feature_col,
):
    # ROC curve using all gene pairs
    fpr, tpr, thr = roc_curve(data[target_col], data[feature_col])
    auroc = roc_auc_score(data[target_col], data[feature_col])
    
    return fpr, tpr, thr, auroc

# %%
def fig_to_panels(fig, axes, output_dir):
    # Save individual panels of a figure 
    
    for panel_name, ax in axes.items():
        # Extract the panel title
        panel_title = ax.get_title()

        # Sanitize the panel title to use in filenames
        safe_title = panel_title.replace(" ", "_").replace("/", "_").replace("\n", "_").lower()

        # Create the filename for the current panel
        output_file = os.path.join(output_dir,safe_title)

        # Adjust the bounding box to include everything (labels, titles, etc.)
        extent = ax.get_tightbbox(fig.canvas.get_renderer()).transformed(fig.dpi_scale_trans.inverted())

        # Save the individual panel using the adjusted bounding box
        fig.savefig(output_file + '.pdf', bbox_inches=extent, dpi=300)
        fig.savefig(output_file + '.png', bbox_inches=extent)

        print(f"Saved panel '{panel_title}' to {output_file}")

# %%
# Define colors
# Light version is obtained by setting alpha=0.5

ncolor  = '#00728eff' # solid dark
ncolor2 = '#00728e80' # alpha=0.5
lightncolor = '#7fb8c6ff' # solid light

tcolor  = '#ab3502ff'
tcolor2 = '#ab350280'
lighttcolor = '#d49980ff'

graycolor = '#4D4E4FFF'
graycolor2 ='#4d4e4f80'

lightgray = '#C8CAD4'

orangecolor = '#e69426'
orangecolor2 = '#e6942680'
lightorangecolor = '#f2c992ff'

# %%
def network_to_adj(network_path):
    network = pd.read_csv(
        network_path,
        usecols=['complex1', 'complex2', 'adj']
    )

    # Add a mirrored version of the network to make it symmetric
    network_mirrored = network.copy()
    network_mirrored.columns = ['complex2', 'complex1', 'adj']
    network = pd.concat([network, network_mirrored], ignore_index=True)

    adj = network.pivot(index='complex1', columns='complex2', values='adj').fillna(0)
    return adj

# %% [markdown]
# # GPCRs

# %%
# Read GPCRs
gpcrs = pd.read_csv('/home/fraimondi/BIOINFO1_BK/francesco/GPCR/gpcrs_genes.txt')['Symbol'].values

# Read ligands
lr = pd.read_csv('/home/lnemati/pathway_crosstalk/data/interactions/ccc_lr_pairs.csv')
lr = lr[lr.receptor.isin(gpcrs)]

# Read G-Proteins coupling
gprots_couplings = pd.read_csv('/home/lnemati/resources/gpcr_couplings/gpcr_couplings.csv')
gprots_couplings = gprots_couplings.query('n_sources >=3')
gprots_couplings = gprots_couplings.query('type != "precogx_only"')
gprots_couplings.set_index('gpcr', inplace=True, drop=False)
gprots_couplings.index.name = None
gprots_couplings = gprots_couplings.groupby('gpcr')['gprot'].apply(list)
gprots = gprots_couplings.values.sum()

# %%
# Get G-Proteins, GPCRs and their ligands
gpcrs_genes = set(gpcrs) | set(gprots) | set(lr.ligand.values) | set(lr.receptor.values)

# %%
ncoev = pd.read_csv('/home/lnemati/pathway_crosstalk/results/gpcrs/normal_jaccard_coevolution.csv', index_col=0)

df = pd.DataFrame(columns=['gpcr', 'interactor', 'interactor_type', 'condition', 'value'])

for gpcr in gprots_couplings.index.intersection(ncoev.index):
    couplings = ncoev.index.intersection(gprots_couplings.loc[gpcr])
    values = ncoev.loc[gpcr, couplings].to_frame(name = 'value')
    values['gpcr'] = gpcr
    values['interactor'] = values.index
    values['interactor_type'] = 'G-Protein'
    values['tissue'] = 'Coevolution'
    values['condition'] = 'Coevolution'
    values['value_type'] = 'jaccard'

    df = pd.concat([df, values])
    
for gpcr in ncoev.index.intersection(lr.receptor.unique()):
    ligands = ncoev.index.intersection(lr[lr['receptor'] == gpcr].ligand.unique())
    values = ncoev.loc[gpcr, ligands].to_frame(name = 'value')
    values['gpcr'] = gpcr
    values['interactor'] = values.index
    values['interactor_type'] = 'Ligand'
    values['tissue'] = 'Coevolution'
    values['condition'] = 'Coevolution'
    values['value_type'] = 'jaccard'

    df = pd.concat([df, values])

df = df.reset_index(drop=True)

# %%
ncoev_jaccard = df.query('tissue == "Coevolution"')

# %%
df.query('value_type == "jaccard"')['value'].min()
# Out:
# 0.0375782881002087

# %%
df = pd.concat([df, pd.read_csv('/home/lnemati/pathway_crosstalk/results/gpcrs/all_gpcr_interactions.csv')])
#df = df[df['subtissue'] != 'testis']
df.query('not (subtissue == "testis" and condition == "normal")')
df = df.groupby(['gpcr', 'interactor', 'condition', 'interactor_type', 'tissue', 'value_type'], as_index=False)['value'].mean()
df = df.query('value_type in ["correlation", "jaccard"]')

# %%
df['condition'] =df['condition'].replace({'normal': 'Normal Co-Expression', 'tumor': 'Tumor Co-Expression'})

# %%
# Filter out 0 values
#df = df[df['value'] != 0]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(19,6))

ax1.set_title('Normal Co-expression')
ax1.set_xlabel('Correlation')
ndf = df[df['condition'] == 'Normal Co-Expression']
sns.ecdfplot(x='value', hue='interactor_type', data=ndf, ax=ax1, palette={'G-Protein': lightgray, 'Ligand': ncolor})
sns.rugplot(x='value', hue='interactor_type', data=ndf, ax=ax1, palette={'G-Protein': lightgray, 'Ligand': ncolor})

ax2.set_title('Tumor Co-expression')
ax2.set_xlabel('Correlation')
tdf = df[df['condition'] == 'Tumor Co-Expression']
sns.ecdfplot(x='value', hue='interactor_type', data=tdf, ax=ax2, palette={'G-Protein': lightgray, 'Ligand': tcolor})
sns.rugplot(x='value', hue='interactor_type', data=tdf, ax=ax2, palette={'G-Protein': lightgray, 'Ligand': tcolor})

ax3.set_title('Coevolution')
ax3.set_xlabel('Jaccard Index')
ncdf = df[df['condition'] == 'Coevolution']
sns.ecdfplot(x='value', hue='interactor_type', data=ncdf, ax=ax3, palette={'G-Protein': lightgray, 'Ligand': orangecolor})
sns.rugplot(x='value', hue='interactor_type', data=ncdf, ax=ax3, palette={'G-Protein': lightgray, 'Ligand': orangecolor})

#plt.savefig('/home/lnemati/pathway_crosstalk/results/gpcrs/cumulative_distribution.pdf', bbox_inches='tight')
#plt.savefig('/home/lnemati/pathway_crosstalk/results/gpcrs/cumulative_distribution.png', bbox_inches='tight')
# Out:
# <Axes: title={'center': 'Coevolution'}, xlabel='Jaccard Index', ylabel='Proportion'>

# %%
    # Define a function to plot the CDFs and highlight the D-statistic
    def plot_cdf_with_ks(data, condition, ax, color_ligand, color_gpcr):
        fs = 18

        # Filter data for the given condition
        df_condition = data[data['condition'] == condition]
        ligand_values = df_condition[df_condition['interactor_type'] == 'Ligand']['value']
        gpcr_values = df_condition[df_condition['interactor_type'] == 'G-Protein']['value']

        # Perform KS test
        ks_stat, p_value = ks_2samp(ligand_values, gpcr_values)

        # Plot the ECDF for Ligand
        sns.ecdfplot(ligand_values, ax=ax, color=color_ligand, label='Ligand', linewidth=3)
        # Plot the ECDF for G-Protein
        sns.ecdfplot(gpcr_values, ax=ax, color=color_gpcr, label='G-Protein', linewidth=3)

        # Highlight the maximum difference (D-statistic)
        cdf_ligand = np.sort(ligand_values)
        cdf_gpcr = np.sort(gpcr_values)
        all_values = np.sort(np.unique(np.concatenate((cdf_ligand, cdf_gpcr))))
        cdf_ligand_y = np.searchsorted(cdf_ligand, all_values, side='right') / len(cdf_ligand)
        cdf_gpcr_y = np.searchsorted(cdf_gpcr, all_values, side='right') / len(cdf_gpcr)
        max_diff_index = np.argmax(np.abs(cdf_ligand_y - cdf_gpcr_y))

        x_max_diff = all_values[max_diff_index]
        y1_max_diff = cdf_ligand_y[max_diff_index]
        y2_max_diff = cdf_gpcr_y[max_diff_index]
        midpoint_y = (y1_max_diff + y2_max_diff) / 2

        # Add the D-statistic line with arrowheads
        ax.vlines(all_values[max_diff_index], cdf_ligand_y[max_diff_index], cdf_gpcr_y[max_diff_index], 
                  color='k', linestyle='-', lw=2)
        ax.arrow(x_max_diff, y1_max_diff, 0, y2_max_diff - y1_max_diff, 
                 color='k', linestyle='-', lw=2, head_width=0.02, head_length=0.02, length_includes_head=True, zorder=10)
        ax.arrow(x_max_diff, y2_max_diff, 0, y1_max_diff - y2_max_diff, 
                 color='k', linestyle='-', lw=2, head_width=0.02, head_length=0.02, length_includes_head=True, zorder=10)

        # Add the D-statistic and p-value as text (using transAxes)
        text_object = ax.text(
            0.35, 0.85,
            f'D = {ks_stat:.2f}\np = {p_value:.1e}',
            fontsize=fs - 2, ha='right', va='center',
            transform=ax.transAxes,
        )

        # Get the coordinates of the text after it's transformed (axis-relative)
        text_x, text_y = text_object.get_position()

        # Convert the data coordinates of the max_diff and midpoint_y to axis-relative
        max_diff_axis_rel = ax.transData.transform((x_max_diff, midpoint_y))
        max_diff_axis_rel_x, max_diff_axis_rel_y = ax.transAxes.inverted().transform(max_diff_axis_rel)

        # Calculate the direction of the line (vector from text to midpoint)
        direction_x = max_diff_axis_rel_x - text_x
        direction_y = max_diff_axis_rel_y - text_y

        # Adjust the distance of the line to make it shorter (scale by a factor of 0.8)
        offset_x = direction_x * 0.85
        offset_y = direction_y * 0.85

        # Compute new coordinates for the endpoints
        start_x = text_x + offset_x
        start_y = text_y + offset_y
        end_x = max_diff_axis_rel_x - offset_x
        end_y = max_diff_axis_rel_y - offset_y

        # Plot a thin line connecting the text annotation to the midpoint of the D-statistic (shortened)
        ax.plot([start_x, end_x], [start_y, end_y], color='k', lw=1, linestyle='-', zorder=9, transform=ax.transAxes)

        # Add title, legend, and labels
        ax.set_title(f'{condition}', fontsize=fs)
        ax.set_xlabel('Value', fontsize=fs)
        ax.set_ylabel('Cumulative Probability', fontsize=fs)
        ax.tick_params(labelsize=fs)

        # Add the legend for the two groups only
        ax.legend(fontsize=fs, loc='lower right')
        ax.grid(False)

# Create subplots for each condition
fig, axes = plt.subplots(1, 3, figsize=(19, 6))

# Plot for Normal Co-expression
plot_cdf_with_ks(df, 'Normal Co-Expression', axes[0], ncolor, lightgray)

# Plot for Tumor Co-expression
plot_cdf_with_ks(df, 'Tumor Co-Expression', axes[1], tcolor, lightgray)

# Plot for Coevolution
plot_cdf_with_ks(df, 'Coevolution', axes[2], orangecolor, lightgray)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
print('Tumor: ligands vs gprots')
xx = tdf[(tdf['interactor_type'] == 'Ligand')].value
yy = tdf[(tdf['interactor_type'] == 'G-Protein')].value

result = mannwhitneyu(xx, yy)
auroc = result.statistic / (len(xx) * len(yy))
pval = result.pvalue
print('  ',auroc, pval)

print('Normal: ligands vs gprots')
xx = ndf[(ndf['interactor_type'] == 'Ligand')].value
yy = ndf[(ndf['interactor_type'] == 'G-Protein')].value

result = mannwhitneyu(xx, yy)
auroc = result.statistic / (len(xx) * len(yy))
pval = result.pvalue
print('  ',auroc, pval)

# %%
from matplotlib.lines import Line2D
from matplotlib.pyplot import subplot_mosaic

fs = 12

# Perform Mann-Whitney U test for each 'interactor_type' between 'Tumor Co-Expression' and 'Normal Co-Expression'
types = df['interactor_type'].unique()
conditions = ['Normal Co-Expression', 'Tumor Co-Expression', 'Coevolution']
p_values = []
comparisons = []
aurocs = []

# Plot the violin and strip plot as before
fig, axes = subplot_mosaic(
    mosaic="""
    ABC
    ABC
    DDE
    DDE
    DDE
    """,
    figsize=(8.27, 11.69)
)

# Cumulative distributions
axes['A'].set_title('Normal Co-expression (CDF)', fontsize=fs)
axes['A'].set_xlabel('Correlation', fontsize=fs)
ndf = df[df['condition'] == 'Normal Co-Expression']
sns.ecdfplot(x='value', hue='interactor_type', data=ndf, ax=axes['A'], palette={'G-Protein': lightgray, 'Ligand': ncolor})
sns.rugplot(x='value', hue='interactor_type', data=ndf, ax=axes['A'], palette={'G-Protein': lightgray, 'Ligand': ncolor})
axes['A'].set_xlim(ndf.value.min(), ndf.value.max())

axes['B'].set_title('Tumor Co-expression (CDF)', fontsize=fs)
axes['B'].set_xlabel('Correlation', fontsize=fs)
tdf = df[df['condition'] == 'Tumor Co-Expression']
sns.ecdfplot(x='value', hue='interactor_type', data=tdf, ax=axes['B'], palette={'G-Protein': lightgray, 'Ligand': tcolor})
sns.rugplot(x='value', hue='interactor_type', data=tdf, ax=axes['B'], palette={'G-Protein': lightgray, 'Ligand': tcolor})
axes['B'].set_xlim(tdf.value.min(), tdf.value.max())

axes['C'].set_title('Coevolution (CDF)', fontsize=fs)
axes['C'].set_xlabel('Jaccard Index', fontsize=fs)
ncdf = df[df['condition'] == 'Coevolution']
sns.ecdfplot(x='value', hue='interactor_type', data=ncdf, ax=axes['C'], palette={'G-Protein': lightgray, 'Ligand': orangecolor})
sns.rugplot(x='value', hue='interactor_type', data=ncdf, ax=axes['C'], palette={'G-Protein': lightgray, 'Ligand': orangecolor})
axes['C'].set_xlim(ncdf.value.min(), ncdf.value.max())


palette_light = {'Normal Co-Expression': lightncolor, 'Tumor Co-Expression': lighttcolor, 'Coevolution': lightorangecolor}
palette = {'Normal Co-Expression': ncolor, 'Tumor Co-Expression': tcolor, 'Coevolution': orangecolor}

axes['D'].set_title('Co-expression', fontsize=fs)
sns.violinplot(
    x='interactor_type',
    y='value',
    hue='Condition',
    data=df.query('condition != "Coevolution"').rename(columns={'condition': 'Condition'}),
    #palette=palette_light,
    palette=palette,
    ax=axes['D'],
    order=['G-Protein', 'Ligand'],
    hue_order = conditions,
    inner='quart'
)

axes['E'].set_title('Coevolution', fontsize=fs)
sns.violinplot(
    x='interactor_type',
    y='value',
    hue='condition',
    data=df.query('condition == "Coevolution"'),
    #palette=palette_light,
    palette=palette,
    ax=axes['E'],
    order=['G-Protein', 'Ligand'],
    hue_order = conditions,
    inner='quart',
)

# Collect p-values for interactor_type comparisons within each condition
for type_ in types:
    subset = df[df['interactor_type'] == type_]
    tumor_values = subset[subset['condition'] == 'Tumor Co-Expression']['value']
    normal_values = subset[subset['condition'] == 'Normal Co-Expression']['value']
    
    if len(tumor_values) > 0 and len(normal_values) > 0:
        stat, p_value = mannwhitneyu(tumor_values, normal_values, alternative='two-sided')
        aurocs.append(stat / (len(tumor_values) * len(normal_values)))
        p_values.append(p_value)
        comparisons.append((type_, 'Tumor vs Normal'))

# Perform comparisons between Ligand and G-Protein within each condition
for condition in conditions:
    subset = df[df['condition'] == condition]
    ligand_values = subset[subset['interactor_type'] == 'Ligand']['value']
    gprotein_values = subset[subset['interactor_type'] == 'G-Protein']['value']
    
    if len(ligand_values) > 0 and len(gprotein_values) > 0:
        stat, p_value = mannwhitneyu(ligand_values, gprotein_values, alternative='two-sided')
        aurocs.append(stat / (len(ligand_values) * len(gprotein_values)))
        p_values.append(p_value)
        comparisons.append(('Ligand', 'G-Protein', condition))  # Ensure we keep labels consistent here

# Multiple Hypothesis Testing Correction
corrected_p_values = false_discovery_control(p_values)

# Maximum y-value for positioning significance bars
y_max = df['value'].max() + 0.05

# Annotate significance on the plot
for idx, comparison in enumerate(comparisons):        
    corrected_p = corrected_p_values[idx]
    if corrected_p < 0.001:
        annotation = '***'
    elif corrected_p < 0.01:
        annotation = '**'
    elif corrected_p < 0.05:
        annotation = '*'
    else:
        annotation = 'ns'  # Not significant
    
    if len(comparison) == 3:  # Ligand vs G-Protein comparisons
        condition = comparison[2]
        
        if condition == 'Coevolution':
            # Plot on ax['E'] for Coevolution
            x_offset = 0.27  # Align with the Coevolution category
            target_ax = axes['E']
            x1 = 0.
            x2 = 1
            y = 1.1
        else:
            # Plot on ax['D'] for Normal and Tumor Co-Expression
            x_offset = 0 if condition == 'Tumor Co-Expression' else -0.27
            target_ax = axes['D']
        
            x1 = types.tolist().index(comparison[0]) + x_offset
            x2 = types.tolist().index(comparison[1]) + x_offset
            y = y_max + (0.12 * y_max) * idx  # Offset each condition's bars slightly

        target_ax.plot([x1, x1, x2, x2], [y, y + 0.02 * y_max, y + 0.02 * y_max, y], color='k')
        target_ax.text((x1 + x2) / 2, y + 0.03 * y_max, annotation, ha='center', va='bottom', color='k', fontsize=fs)
        
    else:  # Tumor vs Normal comparisons
        type_idx = types.tolist().index(comparison[0])
        x1, x2 = type_idx - 0.27, type_idx
        y = y_max + 0.1 * y_max

        axes['D'].plot([x1, x1, x2, x2], [y, y + 0.02 * y_max, y + 0.02 * y_max, y], color='k')
        axes['D'].text((x1 + x2) / 2, y + 0.03 * y_max, annotation, ha='center', va='bottom', color='k', fontsize=fs)

# Remove duplicate entries in the legend
handles, labels = axes['D'].get_legend_handles_labels()
unique = dict(zip(labels, handles))

# Create custom legend
handles = []

handles = [
    Line2D(
        [0], [0], marker='o', color='w', markerfacecolor=ncolor, 
        markeredgecolor='k', markersize=7, label='Normal Co-Expression'
    ),
    Line2D(
        [0], [0], marker='o', color='w', markerfacecolor=tcolor, 
        markeredgecolor='k', markersize=7, label='Tumor Co-Expression'
    ),
    Line2D(
        [0], [0], marker='o', color='w', markerfacecolor=orangecolor, 
        markeredgecolor='k', markersize=7, label='Coevolution'
    ),
]

lims = (-1.05, 1.88)
limrange = lims[1] - lims[0]
axes['D'].set_ylim(-1, 1.88)
axes['D'].set_yticks([-1, -0.5, 0, 0.5, 1])
axes['D'].legend(loc='upper left')

axes['E'].set_ylim(-0.05, (-0.05+limrange)/2)
axes['E'].set_yticks([0, 0.5, 1])
axes['E'].legend_.remove()

for ax_key, color, label in zip(['A', 'B', 'C'], [ncolor, tcolor, orangecolor], 
                                ['Normal Co-Expression', 'Tumor Co-Expression', 'Coevolution']):
    handles, labels = axes[ax_key].get_legend_handles_labels()
    axes[ax_key].set_ylim(-0.03, 1)
    
    # Redefine handles and labels if they were cleared
    if not handles:  
        handles = [
            Line2D([0], [0], marker='', color=lightgray, label='G-Protein'),
            Line2D([0], [0], marker='', color=color, label='Ligand')
        ]
        
    axes[ax_key].legend(handles=handles, labels=['G-Protein', 'Ligand'], fontsize=fs, bbox_to_anchor=[0.7, 0.105], loc='center')
    axes[ax_key].tick_params(axis='both', labelsize=fs)

axes['D'].set_xlabel(' ', fontsize=0)
axes['D'].set_ylabel('Correlation', fontsize=fs)
axes['D'].tick_params(axis='both', labelsize=fs)

axes['E'].set_xlabel(' ', fontsize=0)
axes['E'].set_ylabel('Jaccard Index', fontsize=fs)
axes['E'].tick_params(axis='both', labelsize=fs)

for ax_key in ['A', 'B', 'C', 'D', 'E']:
    axes[ax_key].spines[['right', 'top']].set_visible(False)
    
plt.tight_layout()

plt.savefig('/home/lnemati/pathway_crosstalk/results/figures/gpcrs/gpcrs_figure.pdf', bbox_inches='tight')
plt.savefig('/home/lnemati/pathway_crosstalk/results/figures/gpcrs/gpcrs_figure.png', bbox_inches='tight')

plt.show()

# %%
from matplotlib import pyplot as plt

# Loop through each subplot in the `axes` dictionary
for panel_name, ax in axes.items():
    # Extract the panel title
    panel_name = ax.get_title()
    
    # Sanitize the panel title to use in filenames
    safe_title = panel_name.replace(" ", "_").replace("/", "_").lower()

    # Create the filename for the current panel
    output_file = f'/home/lnemati/pathway_crosstalk/results/images/gpcrs/{safe_title}'
    
    # Adjust the bounding box to include everything (labels, titles, etc.)
    extent = ax.get_tightbbox(fig.canvas.get_renderer()).transformed(fig.dpi_scale_trans.inverted())
    
    # Save the individual panel using the adjusted bounding box
    fig.savefig(output_file + '.pdf', bbox_inches=extent, dpi=300)
    fig.savefig(output_file + '.png', bbox_inches=extent)

    print(f"Saved panel {panel_name} to {output_file}")

# %%
fs = 18

# Initialize figure and axes
fig, axes = subplot_mosaic(
    mosaic="""
    ABC
    """,
    figsize=(15, 9)
)

fig.suptitle('Cumulative Distributions of Co-Expression and Coevolution Metrics', fontsize=fs)

# Cumulative distributions for each condition
axes['A'].set_title('Co-Expression (Normal)', fontsize=fs)
axes['A'].set_xlabel('Correlation', fontsize=fs)
axes['A'].set_ylabel('Proportion', fontsize=fs)
ndf = df[df['condition'] == 'Normal Co-Expression']
sns.ecdfplot(x='value', hue='interactor_type', data=ndf, ax=axes['A'], palette={'G-Protein': lightgray, 'Ligand': ncolor}, lw=3)
sns.rugplot(x='value', hue='interactor_type', data=ndf.query('interactor_type == "Ligand"'), ax=axes['A'], palette={'Ligand': ncolor}, alpha=0.05)
axes['A'].set_xlim(ndf.value.min(), ndf.value.max())

axes['B'].set_title('Co-Expression (Tumor)', fontsize=fs)
axes['B'].set_xlabel('Correlation', fontsize=fs)
axes['B'].set_ylabel('Proportion', fontsize=fs)
tdf = df[df['condition'] == 'Tumor Co-Expression']
sns.ecdfplot(x='value', hue='interactor_type', data=tdf, ax=axes['B'], palette={'G-Protein': lightgray, 'Ligand': tcolor}, lw=3)
sns.rugplot(x='value', hue='interactor_type', data=tdf.query('interactor_type == "Ligand"'), ax=axes['B'], palette={'Ligand': tcolor}, alpha=0.05)
axes['B'].set_xlim(tdf.value.min(), tdf.value.max())

axes['C'].set_title('Coevolution (Orthology)', fontsize=fs)
axes['C'].set_xlabel('Jaccard Index', fontsize=fs)
axes['C'].set_ylabel('Proportion', fontsize=fs)
ncdf = df[df['condition'] == 'Coevolution']
sns.ecdfplot(x='value', hue='interactor_type', data=ncdf, ax=axes['C'], palette={'G-Protein': lightgray, 'Ligand': orangecolor}, lw=3)
sns.rugplot(x='value', hue='interactor_type', data=ncdf.query('interactor_type == "Ligand"'), ax=axes['C'], palette={'Ligand': orangecolor}, alpha=0.5)
axes['C'].set_xlim(ncdf.value.min(), ncdf.value.max())

# Set legend and axis styles
for ax_key, color, label in zip(['A', 'B', 'C'], [ncolor, tcolor, orangecolor], 
                                ['Normal Co-Expression', 'Tumor Co-Expression', 'Coevolution']):
    handles, labels = axes[ax_key].get_legend_handles_labels()
    axes[ax_key].set_ylim(-0.03, 1)
    
    if not handles:  
        handles = [
            Line2D([0], [0], marker='', color=lightgray, label='G-Protein'),
            Line2D([0], [0], marker='', color=color, label='Ligand')
        ]
        
    axes[ax_key].legend(handles=handles, labels=['G-Protein', 'Ligand'], fontsize=fs, bbox_to_anchor=[0.7, 0.105], loc='center')
    axes[ax_key].tick_params(axis='both', labelsize=fs)

for ax_key in ['A', 'B', 'C']:
    axes[ax_key].spines[['right', 'top']].set_visible(False)

plt.savefig('/home/lnemati/pathway_crosstalk/results/figures/gpcrs/gpcrs_cumulative.pdf', bbox_inches='tight')
    
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np
from scipy.stats import ks_2samp

# Define function to plot the CDF and D-statistic lines with shortened connection line
def plot_cdf_with_ks(data, condition, ax, color_ligand, color_gpcr, fs):
    # Filter data for the given condition
    df_condition = data[data['condition'] == condition]
    ligand_values = df_condition[df_condition['interactor_type'] == 'Ligand']['value']
    gpcr_values = df_condition[df_condition['interactor_type'] == 'G-Protein']['value']

    # Perform KS test
    ks_stat, p_value = ks_2samp(ligand_values, gpcr_values)

    # Plot the ECDF for Ligand
    sns.ecdfplot(ligand_values, ax=ax, color=color_ligand, label='Ligand', linewidth=3)
    # Plot the ECDF for G-Protein
    sns.ecdfplot(gpcr_values, ax=ax, color=color_gpcr, label='G-Protein', linewidth=3)

    # Highlight the maximum difference (D-statistic)
    cdf_ligand = np.sort(ligand_values)
    cdf_gpcr = np.sort(gpcr_values)
    all_values = np.sort(np.unique(np.concatenate((cdf_ligand, cdf_gpcr))))
    cdf_ligand_y = np.searchsorted(cdf_ligand, all_values, side='right') / len(cdf_ligand)
    cdf_gpcr_y = np.searchsorted(cdf_gpcr, all_values, side='right') / len(cdf_gpcr)
    max_diff_index = np.argmax(np.abs(cdf_ligand_y - cdf_gpcr_y))
    
    x_max_diff = all_values[max_diff_index]
    y1_max_diff = cdf_ligand_y[max_diff_index]
    y2_max_diff = cdf_gpcr_y[max_diff_index]
    midpoint_y = (y1_max_diff + y2_max_diff) / 2

    # Add the D-statistic line with arrowheads
    ax.vlines(all_values[max_diff_index], cdf_ligand_y[max_diff_index], cdf_gpcr_y[max_diff_index], 
              color='k', linestyle='-', lw=1)
    ax.arrow(x_max_diff, y1_max_diff, 0, y2_max_diff - y1_max_diff, 
             color='k', linestyle='-', lw=1, head_width=0.02, head_length=0.02, length_includes_head=True, zorder=10)
    ax.arrow(x_max_diff, y2_max_diff, 0, y1_max_diff - y2_max_diff, 
             color='k', linestyle='-', lw=1, head_width=0.02, head_length=0.02, length_includes_head=True, zorder=10)

    # Add the D-statistic and p-value as text (using transAxes)
    text_object = ax.text(
        0.35, 0.85,
        f'D = {ks_stat:.2f}\np = {p_value:.1e}',
        fontsize=fs - 2, ha='right', va='center',
        transform=ax.transAxes,
    )
    
    # Get the coordinates of the text after it's transformed (axis-relative)
    text_x, text_y = text_object.get_position()

    # Convert the data coordinates of the max_diff and midpoint_y to axis-relative
    max_diff_axis_rel = ax.transData.transform((x_max_diff, midpoint_y))
    max_diff_axis_rel_x, max_diff_axis_rel_y = ax.transAxes.inverted().transform(max_diff_axis_rel)

    # Calculate the direction of the line (vector from text to midpoint)
    direction_x = max_diff_axis_rel_x - text_x
    direction_y = max_diff_axis_rel_y - text_y
    
    # Adjust the distance of the line to make it shorter (scale by a factor of 0.8)
    offset_x = direction_x * 0.8
    offset_y = direction_y * 0.8
    
    # Compute new coordinates for the endpoints
    start_x = text_x + offset_x
    start_y = text_y + offset_y
    end_x = max_diff_axis_rel_x - offset_x
    end_y = max_diff_axis_rel_y - offset_y
    
    # Plot a thin line connecting the text annotation to the midpoint of the D-statistic (shortened)
    ax.plot([start_x, end_x], [start_y, end_y], color='k', lw=0.8, linestyle='-', zorder=9, transform=ax.transAxes)

    ax.tick_params(labelsize=fs)

# Initialize figure and axes
fig, axes = plt.subplot_mosaic(
    mosaic="""
    ABC
    """,
    figsize=(15, 5)
)

fig.suptitle('Cumulative Distributions of Co-Expression and Coevolution Metrics', fontsize=fs)

# Cumulative distributions for each condition
axes['A'].set_title('Co-Expression (Normal)', fontsize=fs)
axes['A'].set_xlabel('Correlation', fontsize=fs)
axes['A'].set_ylabel('Cumulative Probability', fontsize=fs)
ndf = df[df['condition'] == 'Normal Co-Expression']
sns.ecdfplot(x='value', hue='interactor_type', data=ndf, ax=axes['A'], palette={'G-Protein': lightgray, 'Ligand': ncolor}, lw=3)
#sns.rugplot(x='value', hue='interactor_type', data=ndf.query('interactor_type == "Ligand"'), ax=axes['A'], palette={'Ligand': ncolor}, alpha=0.05)
axes['A'].set_xlim(ndf.value.min(), ndf.value.max())

# Apply the shortened D-statistic annotation
plot_cdf_with_ks(df, 'Normal Co-Expression', axes['A'], ncolor, lightgray, fs)

axes['B'].set_title('Co-Expression (Tumor)', fontsize=fs)
axes['B'].set_xlabel('Correlation', fontsize=fs)
axes['B'].set_ylabel('Cumulative Probability', fontsize=fs)
tdf = df[df['condition'] == 'Tumor Co-Expression']
sns.ecdfplot(x='value', hue='interactor_type', data=tdf, ax=axes['B'], palette={'G-Protein': lightgray, 'Ligand': tcolor}, lw=3)
#sns.rugplot(x='value', hue='interactor_type', data=tdf.query('interactor_type == "Ligand"'), ax=axes['B'], palette={'Ligand': tcolor}, alpha=0.05)
axes['B'].set_xlim(tdf.value.min(), tdf.value.max())

# Apply the shortened D-statistic annotation
plot_cdf_with_ks(df, 'Tumor Co-Expression', axes['B'], tcolor, lightgray, fs)

axes['C'].set_title('Coevolution (Orthology)', fontsize=fs)
axes['C'].set_xlabel('Jaccard Index', fontsize=fs)
axes['C'].set_ylabel('Cumulative Probability', fontsize=fs)
ncdf = df[df['condition'] == 'Coevolution']
sns.ecdfplot(x='value', hue='interactor_type', data=ncdf, ax=axes['C'], palette={'G-Protein': lightgray, 'Ligand': orangecolor}, lw=3)
#sns.rugplot(x='value', hue='interactor_type', data=ncdf.query('interactor_type == "Ligand"'), ax=axes['C'], palette={'Ligand': orangecolor}, alpha=0.5)
axes['C'].set_xlim(ncdf.value.min(), ncdf.value.max())

# Apply the shortened D-statistic annotation
plot_cdf_with_ks(df, 'Coevolution', axes['C'], orangecolor, lightgray, fs)

# Set legend and axis styles
for ax_key, color, label in zip(['A', 'B', 'C'], [ncolor, tcolor, orangecolor], ['Normal Co-Expression', 'Tumor Co-Expression', 'Coevolution']):
    handles, labels = axes[ax_key].get_legend_handles_labels()
    axes[ax_key].set_ylim(-0., 1)
    
    if not handles:  
        handles = [
            Line2D([0], [0], marker='', color=lightgray, label='G-Protein'),
            Line2D([0], [0], marker='', color=color, label='Ligand')
        ]
        
    axes[ax_key].legend(handles=handles, fontsize=fs, bbox_to_anchor=[0.7, 0.105], loc='center')
    axes[ax_key].tick_params(axis='both', labelsize=fs)

for ax_key in ['A', 'B', 'C']:
    axes[ax_key].spines[['right', 'top']].set_visible(False)

plt.savefig('/home/lnemati/pathway_crosstalk/results/figures/gpcrs/gpcrs_cumulative_ks.pdf', bbox_inches='tight', dpi=300)
plt.savefig('/home/lnemati/pathway_crosstalk/results/figures/gpcrs/gpcrs_cumulative_ks.png', bbox_inches='tight', dpi=300)
plt.savefig('/home/lnemati/pathway_crosstalk/results/figures/gpcrs/gpcrs_cumulative_ks.svg', bbox_inches='tight', dpi=300)
    
# Display the plot
plt.show()

# %%
counts = df.groupby('tissue')['condition'].nunique()
tissues_both = counts[counts == 2].index

nauroc = {}
tauroc = {}
diff = {}

for tissue, tissue_df in df.query('tissue in @tissues_both and condition != "Coevolution"').groupby('tissue'):    
    for condition in ['Normal Co-Expression', 'Tumor Co-Expression']:
        subset = tissue_df[tissue_df['condition'] == condition]
        ligand_values = subset[subset['interactor_type'] == 'Ligand']['value']
        gprotein_values = subset[subset['interactor_type'] == 'G-Protein']['value']

        if len(ligand_values) > 0 and len(gprotein_values) > 0:
            stat, p_value = mannwhitneyu(ligand_values, gprotein_values, alternative='two-sided')
            auroc = stat / (len(ligand_values) * len(gprotein_values))
            
            if condition == 'Normal Co-Expression':
                nauroc[tissue] = auroc
                
            if condition == 'Tumor Co-Expression':
                tauroc[tissue] = auroc
                
tauroc = pd.Series(tauroc)
tauroc.name = 'tumor_auroc'

nauroc = pd.Series(nauroc)
nauroc.name = 'normal_auroc'

aurocs = tauroc.to_frame().join(nauroc)
aurocs['diff'] = aurocs['tumor_auroc'] - aurocs['normal_auroc']
aurocs = aurocs.sort_values(by='diff')
aurocs
# Out:
#                tumor_auroc  normal_auroc      diff
# colon             0.439403      0.546214 -0.106811
# adrenal_gland     0.505166      0.529230 -0.024064
# prostate          0.483303      0.498082 -0.014779
# liver             0.517066      0.528460 -0.011395
# esophagus         0.540353      0.538138  0.002216
# brain             0.582174      0.576331  0.005842
# lung              0.537665      0.525969  0.011696
# kidney            0.504095      0.486557  0.017538
# stomach           0.488485      0.467113  0.021373
# ovary             0.533516      0.509210  0.024305
# thyroid           0.528561      0.483498  0.045062
# testis            0.589921      0.505192  0.084729
# uterus            0.559531      0.471551  0.087980
# pancreas          0.525793      0.431258  0.094535
# breast            0.567247      0.470939  0.096308
# skin              0.595837      0.498175  0.097662

# %%
from scipy.stats import pearsonr, wilcoxon

gprot_diff = {}
ligs_diff = {}
diff = {}

for tissue, tissue_df in df.query('tissue in @tissues_both and condition != "Coevolution"').groupby('tissue'):
    for itype in ['G-Protein', 'Ligand']:
        subset = tissue_df[tissue_df['interactor_type'] == itype]
        
        # Separate Tumor and Normal subsets
        tumor_subset = subset[subset['condition'] == 'Tumor Co-Expression']
        normal_subset = subset[subset['condition'] == 'Normal Co-Expression']
        
        # Match entries using both 'gpcr' and 'interactor' columns
        merged = pd.merge(
            tumor_subset[['gpcr', 'interactor', 'value']].rename(columns={'value': 'tumor_value'}),
            normal_subset[['gpcr', 'interactor', 'value']].rename(columns={'value': 'normal_value'}),
            on=['gpcr', 'interactor']
        )

        if len(merged) > 1:  # Pearson correlation requires at least two points
            # Calculate Pearson correlation

            
            # Store the correlation
            if itype == 'G-Protein':
                gprot_diff[tissue] = p_value
            elif itype == 'Ligand':
                ligs_diff[tissue] = p_value

# %%
from scipy.stats import wilcoxon
import pandas as pd

# Initialize an empty list to collect the data
results = []

# Iterate through tissues and interactor types
for tissue, tissue_df in df.query('tissue in @tissues_both and condition != "Coevolution"').groupby('tissue'):
    for itype in ['G-Protein', 'Ligand']:
        subset = tissue_df[tissue_df['interactor_type'] == itype]
        
        # Separate Tumor and Normal subsets
        tumor_subset = subset[subset['condition'] == 'Tumor Co-Expression']
        normal_subset = subset[subset['condition'] == 'Normal Co-Expression']
        
        # Match entries using both 'gpcr' and 'interactor' columns
        merged = pd.merge(
            tumor_subset[['gpcr', 'interactor', 'value']].rename(columns={'value': 'tumor_value'}),
            normal_subset[['gpcr', 'interactor', 'value']].rename(columns={'value': 'normal_value'}),
            on=['gpcr', 'interactor']
        )

        if len(merged) > 1:  # Wilcoxon test requires at least two points
            # Perform the Wilcoxon signed-rank test
            diff = merged['tumor_value'] - merged['normal_value']
            result = wilcoxon(diff, method='approx')
            p_value = result.pvalue
            z_stat  = result.zstatistic
            
            # Append the result as a dictionary
            results.append({
                'tissue': tissue,
                'interactor_type': itype,
                'z_stat': z_stat,
                'p_value': p_value
            })

# Convert the list of results into a DataFrame
results_df = pd.DataFrame(results)
results_df['pval_adj'] = false_discovery_control(results_df['p_value'])
results_df = results_df.drop(columns='p_value')

# %%
import pandas as pd
from scipy.stats import pearsonr

# Assuming `results_df` and `df` are already loaded DataFrames
corrs_ligand = {}
corrs_gprotein = {}
pvals_ligand = {}
pvals_gprotein = {}

# Loop to compute correlations for Ligands
for tissue in results_df.tissue.unique():
    if tissue == 'testis':
        continue
    # Pivot data for Ligands
    pivot_df = df.query('tissue == @tissue').pivot(index=['gpcr', 'interactor', 'interactor_type'], 
                                                   columns='condition', 
                                                   values='value').reset_index()
    pivot_df = pivot_df[pivot_df['interactor_type'] == 'Ligand']
    pivot_df = pivot_df[pivot_df.isna().sum(1) == 0]
    
    if not pivot_df.empty:
        corrs_ligand[tissue] = pearsonr(pivot_df['Normal Co-Expression'], pivot_df['Tumor Co-Expression']).statistic
        pvals_ligand[tissue] = pearsonr(pivot_df['Normal Co-Expression'], pivot_df['Tumor Co-Expression']).pvalue

# Loop to compute correlations for G-Proteins
for tissue in results_df.tissue.unique():
    if tissue == 'testis':
        continue
    # Pivot data for G-Proteins
    pivot_df = df.query('tissue == @tissue').pivot(index=['gpcr', 'interactor', 'interactor_type'], 
                                                   columns='condition', 
                                                   values='value').reset_index()
    pivot_df = pivot_df[pivot_df['interactor_type'] == 'G-Protein']
    pivot_df = pivot_df[pivot_df.isna().sum(1) == 0]
    
    if not pivot_df.empty:
        corrs_gprotein[tissue] = pearsonr(pivot_df['Normal Co-Expression'], pivot_df['Tumor Co-Expression']).statistic
        pvals_gprotein[tissue] = pearsonr(pivot_df['Normal Co-Expression'], pivot_df['Tumor Co-Expression']).pvalue

# Convert results into a DataFrame
correlation_table = pd.DataFrame({
    "Tissue": list(corrs_ligand.keys()),
    "Ligands": [corrs_ligand[tissue] for tissue in corrs_ligand.keys()],
    "G-Proteins": [corrs_gprotein[tissue] for tissue in corrs_gprotein.keys()]
}).sort_values(by="Ligands", ascending=False)
# Out:
#            Tissue   Ligands  G-Proteins
# 1           brain  0.602401    0.577347
# 13        thyroid  0.542246    0.521351
# 6           liver  0.507339    0.328706
# 10       prostate  0.463089    0.431400
# 5          kidney  0.446957    0.303896
# 12        stomach  0.394911    0.438383
# 4       esophagus  0.378917    0.301951
# 11           skin  0.307010    0.369603
# 8           ovary  0.303906    0.282431
# 3           colon  0.243691    0.347879
# 0   adrenal_gland  0.217272    0.301210
# 7            lung  0.193504    0.139439
# 9        pancreas  0.193337    0.287515
# 14         uterus  0.162886    0.133409
# 2          breast  0.083597    0.141581

# %%
(correlation_table['G-Proteins'] - correlation_table['Ligands']).sort_values()
# Out:
# 6    -0.178633
# 5    -0.143061
# 4    -0.076966
# 7    -0.054065
# 10   -0.031689
# 14   -0.029477
# 1    -0.025054
# 8    -0.021475
# 13   -0.020896
# 12    0.043473
# 2     0.057984
# 11    0.062593
# 0     0.083938
# 9     0.094178
# 3     0.104188
# dtype: float64

# %%
pearsonr(pivot_df['Normal Co-Expression'], pivot_df['Tumor Co-Expression'])
# Out:
# PearsonRResult(statistic=0.13737287182314317, pvalue=1.2285863251751488e-05)

# %%
pivot_df
# Out:
# condition       gpcr interactor interactor_type  Normal Co-Expression  \
# 0          ADCYAP1R1      GNA11       G-Protein             -0.049241
# 1          ADCYAP1R1      GNA14       G-Protein             -0.172865
# 2          ADCYAP1R1      GNA15       G-Protein             -0.136347
# 3          ADCYAP1R1       GNAL       G-Protein              0.084643
# 4          ADCYAP1R1       GNAQ       G-Protein             -0.017937
# ...              ...        ...             ...                   ...
# 1449           VIPR1       GNAQ       G-Protein              0.091910
# 1450           VIPR1       GNAS       G-Protein             -0.187687
# 1451           VIPR1       GNAZ       G-Protein              0.384111
# 1453           VIPR2       GNAL       G-Protein              0.279738
# 1454           VIPR2       GNAS       G-Protein             -0.195394
#
# condition  Tumor Co-Expression
# 0                    -0.042748
# 1                     0.040377
# ...

# %%
pd.Series(corrs).sort_values()[::-1]
# Out:
# brain            0.592953
# thyroid          0.522827
# prostate         0.437156
# stomach          0.428198
# liver            0.377467
# skin             0.355047
# kidney           0.330688
# esophagus        0.323043
# colon            0.305890
# adrenal_gland    0.287292
# ovary            0.285477
# pancreas         0.263533
# lung             0.157328
# uterus           0.137373
# breast           0.120347
# testis           0.075839
# dtype: float64

# %%
from adjustText import adjust_text
import matplotlib.patheffects as path_effects  # Import PathEffects for text outlines

for tissue in results_df.tissue.unique():
    print(tissue)
    
    #Pivot the data to get separate columns for "Tumor" and "Normal" values
    pivot_df = df.query('tissue == @tissue').pivot(index=['gpcr', 'interactor', 'interactor_type'], 
                                                  columns='condition', 
                                                  values='value').reset_index()
    pivot_df = pivot_df[pivot_df.isna().sum(1) == 0]

    plt.figure(figsize=(8, 8))

    # Identify points with high tumor/normal difference
    texts = []  # Collect all text labels to adjust them later
    for i, row in pivot_df.iterrows():
        nval = row['Normal Co-Expression']
        tval = row['Tumor Co-Expression']
        shape = '^' if row['interactor_type'] == 'Ligand' else 'o'

        # Highlight top 1% by tumor-normal difference
        threshold = (pivot_df['Normal Co-Expression'] - pivot_df['Tumor Co-Expression']).abs().quantile(0.99) 

        if np.abs(row['Normal Co-Expression'] - row['Tumor Co-Expression']) > threshold:
            # High Diff
            label = f"{row['gpcr']}-{row['interactor']}"
            color = tcolor if tval > nval else ncolor
            size = 150

            text = plt.text(nval , tval, label, fontsize=9, ha='center', va='center', color='black')
            text.set_path_effects([
                path_effects.Stroke(linewidth=3, foreground='white'),  # White outline
                path_effects.Normal()  # Normal text
            ])
            texts.append(text)

        else:
            size=40
            color = orangecolor if row['interactor_type'] == 'Ligand' else 'lightgray'            

        plt.scatter(nval, tval, s=size, alpha=1, linewidth=1.5, edgecolors='k', color=color, marker=shape)

    # Add labels, title, and legend
    plt.xlim(-1, 1)
    plt.ylim(-1, 1)
    plt.xlabel('Normal Co-Expression (Pearson $r$)')
    plt.ylabel('Tumor Co-Expression (Pearson $r$)')
    plt.title(f'GPCR/Ligand and GPCR/G-Protein Pairs in Tumor and Normal {tissue.title().replace("_", " ")}')
    plt.axhline(0, color='gray', linewidth=0.5)  # Optional: Reference line at y=0
    plt.axvline(0, color='gray', linewidth=0.5)  # Optional: Reference line at x=0
    plt.grid(True, linestyle='--', alpha=0.6)

    handles = [
        Line2D(
            [0], [0], marker='o', color='w', markerfacecolor='lightgray', 
            markeredgecolor='k', markersize=10, label='G-Protein'
        ),
        Line2D(
            [0], [0], marker='^', color='w', markerfacecolor=orangecolor, 
            markeredgecolor='k', markersize=10, label='Ligand'
        ),
    ]

    plt.legend(handles, ['G-Protein', 'Ligand'], loc='lower left', title='Interaction Type', fontsize=fs)

    adjust_text(
            texts,
            x=pivot_df['Normal Co-Expression'],
            y=pivot_df['Tumor Co-Expression'],
            #expand=(5, 5),
            arrowprops=dict(arrowstyle='-', color='k', alpha=0.5),
            #force_points=(10,5),
            force_text=5,
            force_explode=7.5
        )
    
    plt.savefig(f'/home/lnemati/pathway_crosstalk/results/images/gpcrs/scatterplots/{tissue.title()}.pdf', dpi=300, bbox_inches='tight')
    plt.savefig(f'/home/lnemati/pathway_crosstalk/results/images/gpcrs/scatterplots/{tissue.title()}.png', bbox_inches='tight')

    #plt.show()
# Out:
# adrenal_gland
# brain
# breast
# colon
# KeyboardInterrupt
# Error in callback <function _draw_all_if_interactive at 0x7f5889bda4c0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.conda/envs/WGCNA/lib/python3.9/site-packages/matplotlib/pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~/.conda/envs/WGCNA/lib/python3.9/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~/.conda/envs/WGCNA/lib/python3.9/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
# ...

# %% [markdown]
# # Tumor Coevolution - GPCRS

# %%
df_complete = pd.read_csv('/projects/bioinformatics/DB/CancerTracer/intra_heterogeneity_data.txt', sep='\t')

# Remove wrongly formatted row
df_complete = df_complete[~df_complete.index.isin(['p075_p3'])]

# %%
import re
import pandas as pd

def extract_mutation_info(mutation_string, allowed_strings=None):
    # Return empty lists if the input string is missing or empty
    if pd.isna(mutation_string) or mutation_string == '':
        return [], [], []

    # Split the string into individual entries
    gene_entries = mutation_string.split(',')
    
    if allowed_strings is None:
        filtered_entries = [entry for entry in gene_entries]
    else:
    # Filter entries that have allowed patterns and contain a closing parenthesis
        filtered_entries = [entry for entry in gene_entries if any([x in entry for x in allowed_strings]) and ')' in entry]

    # Initialize lists to store genes, mutations, and samples
    genes = []
    mutations = []
    samples = []

    # Process each filtered entry
    for entry in filtered_entries:
        # Get gene: Keep only the text before the first set of parentheses
        gene = re.sub(r'\s*\(.*$', '', entry).strip()

        # Get mutation: Extract the content inside the parentheses
        mutation_match = re.search(r'\(([^()]*)\)', entry)
        mutation = mutation_match.group(1).strip() if mutation_match else ''

        # Get sample: Keep only the text after the first set of parentheses
        sample_match = re.search(r'\(.*?\)\s*([- ]*)(.*)', entry)
        sample = sample_match.group(2).strip('- ').strip() if sample_match else ''

        # Append the parsed components to respective lists
        genes.append(gene)
        mutations.append(mutation)
        samples.append(sample)

    # Return the lists of genes, mutations, and samples
    return genes, mutations, samples

# %%
dfs = []

for col in ['Trunk_mutation', 'Branch_mutation', 'Private_mutation']:
    # Separate individual mutations
    # Use regex to split only on commas that are not inside parentheses
    vals = df_complete[col].str.split(r',\s*(?![^(]*\))', expand=True)
    
    # Find nans
    keep = ~vals.isna()
    
    # Add sample ids
    samples = df_complete['Sample']
    samples.index = samples.values
    vals.index = samples.values
    vals = (vals.T.astype(str) + samples).T
    
    # Remove nans
    vals = vals.values[keep]

    #allowed_strings = ['(p.', '(amp', '(del']
    allowed_strings = None
    
    genes, mutations, samples = extract_mutation_info(", ".join(vals), allowed_strings = allowed_strings)
    
    #genes     = [get_gene(x)     for x in vals]
    #mutations = [get_mutation(x) for x in vals]
    #samples   = [get_sample(x)   for x in vals]
    
    df = pd.DataFrame()
    df.index = genes
    df['mutation'] = mutations
    df['patient'] = samples
    df['when'] = col.strip('_mutation')
    
    dfs.append(df)
    
df = pd.concat(dfs)
#df['when'] = df['when'].map({'Trunk': 'Trunk', 'Private': 'Branch/Private', 'Branch': 'Branch/Private'})
df['gene'] = df.index

df = df[~df.index.isin(['', ' ', '-'])]
df = df[~df['patient'].isin(['', ' ', '-'])]
df = df[~df['gene'].isin(['', ' ', '-'])]

# %%
# Read GPCRs
gpcrs = pd.read_csv('/home/fraimondi/BIOINFO1_BK/francesco/GPCR/gpcrs_genes.txt')['Symbol'].values

# Read ligands
lr = pd.read_csv('/home/lnemati/pathway_crosstalk/data/interactions/ccc_lr_pairs.csv')
gpcrs_lr = lr[lr.receptor.isin(gpcrs)]
gpcrs_ligands = list(set(gpcrs_lr.ligand))

# Read G-Proteins coupling
gprots_couplings = pd.read_csv('/home/lnemati/resources/gpcr_couplings/gpcr_couplings.csv')
gprots = list(set(gprots_couplings.gprot))

gprots_couplings = gprots_couplings.query('n_sources >= 3')
gprots_couplings = gprots_couplings.query('type != "precogx_only"')
gprots_couplings.set_index('gpcr', inplace=True, drop=False)
gprots_couplings.index.name = None
gprots_couplings = gprots_couplings.groupby('gpcr')['gprot'].apply(list)

# %%
ccc_genes = set(lr.receptor).union(lr.ligand)

# %%
# Get G-Proteins, GPCRs and their ligands
gpcrs_genes = set(gpcrs) | set(gprots) | set(gpcrs_lr.ligand.values)# | set(gpcrs_lr.receptor.values)

# %%
#gpcrs_tcoev = df[df['gene'].isin(gpcrs_genes)]
#patients_per_gene = gpcrs_tcoev.groupby('gene')['patient'].unique()

# %%
df['gpcr'] = df.gene.isin(gpcrs)
df['gprot'] = df.gene.isin(gprots)
df['ligand'] = df.gene.isin(gpcrs_ligands)

# %%
df.index = (df['patient'] + '_' + df['gene'])
df['unique_id'] = (df['patient'] + '_' + df['gene'])

# %%
counts = df.groupby(['unique_id', 'when']).size().reset_index(name='count')
counts = counts.sort_values(by='count', ascending=False)
counts['patient'] = counts['unique_id'].str.split('_').apply(lambda x: '_'.join(x[:-1]))
counts['gene'] = counts['unique_id'].str.split('_').apply(lambda x: '_'.join(x[-1:]))

counts['ccc'] = False
counts.loc[counts.gene.isin(ccc_genes), 'ccc'] = True

# %%
genes = counts.groupby(['gene', 'when'])['count'].sum().to_frame()

# %%
genes['gene'] = genes.index.get_level_values(0)
genes['when'] = genes.index.get_level_values(1)
genes.index = range(len(genes))

# %%
# Group by 'gene' and calculate the total counts for each gene
total_counts = genes.groupby('gene')['count'].sum()

# Sort genes by total count in descending order
genes = genes.set_index('gene').loc[total_counts.sort_values(ascending=False).index].reset_index()

# %%
## Init df for test results
results = pd.DataFrame(columns=['auroc', 'pval'])

genes_pivot = genes.pivot(index='gene', columns='when', values='count').fillna(0)
genes_pivot = genes_pivot.loc[total_counts.sort_values(ascending=False).index]

# All genes
genes_pivot_all = genes_pivot
total_all_log10 = np.log10(genes_pivot_all.sum(axis=1))
total_lig_log10 = total_all_log10.loc[total_all_log10.index.isin(gpcrs_ligands)]
total_gprot_log10 = total_all_log10.loc[total_all_log10.index.isin(gprots)]
total_gpcr_log10 = total_all_log10.loc[total_all_log10.index.isin(gpcrs)]

# Log10 Total comparisons
for label, subset, drop_ids in [
    ('ligand vs all', total_lig_log10, gpcrs_ligands),
    ('gprot vs all', total_gprot_log10, gprots),
    ('gpcr vs all', total_gpcr_log10, gpcrs)
]:
    others = total_all_log10.drop(drop_ids, errors='ignore')
    result = mannwhitneyu(subset, others)
    auroc = result.statistic / (len(subset) * len(others))
    results.loc[label, 'auroc'] = auroc
    results.loc[label, 'pval'] = result.pvalue
    results.loc[label, 'tested_quantity'] = 'Log10 Total'

# Normalize Trunk, Branch, and Private by Total
genes_norm = genes_pivot.T.div(genes_pivot.sum(axis=1)).T    

# Normalize Trunk, Branch, and Private by Total for each gene
#genes_norm = genes_pivot.T.div(genes_pivot.sum(axis=1)).T

# Now repeat for Trunk, Branch, and Private
for col in ['Trunk', 'Branch', 'Private']:
    for label, ids in [
        ('ligand vs all', gpcrs_ligands),
        ('gprot vs all', gprots),
        ('gpcr vs all', gpcrs)
    ]:
        group = genes_norm.loc[genes_norm.index.isin(ids), col]
        background = genes_norm.drop(ids, errors='ignore')[col]
        result = mannwhitneyu(group, background)
        auroc = result.statistic / (len(group) * len(background))
        results.loc[f'{label} {col}', 'auroc'] = auroc
        results.loc[f'{label} {col}', 'pval'] = result.pvalue
        results.loc[f'{label} {col}', 'tested_quantity'] = col

# Apply multiple testing correction
results['pval_adj'] = false_discovery_control(results.pval.astype(float).values)

# Optional: reorder if you still want just a specific subset
# results = results.loc[['log10 Total', 'Trunk', 'Branch', 'Private']]

# %%
results.sort_values(by='pval')
# Out:
#                           auroc      pval tested_quantity  pval_adj
# gpcr vs all            0.570892  0.000002     Log10 Total  0.000028
# ligand vs all           0.45838  0.021097     Log10 Total  0.126581
# gpcr vs all Trunk      0.528261   0.05781           Trunk  0.231239
# gprot vs all Branch    0.600934  0.159391          Branch  0.478173
# gprot vs all            0.59087  0.221009     Log10 Total  0.530422
# gprot vs all Trunk     0.420515  0.280943           Trunk  0.561886
# gpcr vs all Private    0.512159   0.41762         Private  0.715920
# gprot vs all Private   0.541518  0.575975         Private  0.803111
# ligand vs all Branch   0.491259  0.616127          Branch  0.803111
# ligand vs all Trunk    0.492346  0.669259           Trunk  0.803111
# gpcr vs all Branch     0.503762  0.795239          Branch  0.828487
# ligand vs all Private  0.503909  0.828487         Private  0.828487

# %%
# Calculate total mutation counts per gene
gene_totals = genes_pivot_all.sum(axis=1)
valid_genes = gene_totals >= 0  # discard genes with few mutations

# Define normalized subsets
genes_all_norm = genes_norm.copy()
genes_gpcr_norm = genes_norm.loc[genes_norm.index.isin(gpcrs)]
genes_gprot_norm = genes_norm.loc[genes_norm.index.isin(gprots)]
genes_lig_norm = genes_norm.loc[genes_norm.index.isin(gpcrs_ligands)]

# Filter only for right panel (proportional data)
genes_all_filt = genes_all_norm.loc[genes_all_norm.index.isin(valid_genes[valid_genes].index)]
genes_gpcr_filt = genes_gpcr_norm.loc[genes_gpcr_norm.index.isin(valid_genes[valid_genes].index)]
genes_gprot_filt = genes_gprot_norm.loc[genes_gprot_norm.index.isin(valid_genes[valid_genes].index)]
genes_lig_filt = genes_lig_norm.loc[genes_lig_norm.index.isin(valid_genes[valid_genes].index)]

# Build dataframe
data = pd.DataFrame({
    'Metric': ['log10 Total'] * len(total_gpcr_log10) +
              ['log10 Total'] * len(total_gprot_log10) +
              ['log10 Total'] * len(total_lig_log10) +
              ['log10 Total'] * len(total_all_log10),
    'Gene Type': ['gpcr'] * len(total_gpcr_log10) +
                 ['gprot'] * len(total_gprot_log10) +
                 ['ligand'] * len(total_lig_log10) +
                 ['all_genes'] * len(total_all_log10),
    'Value': np.concatenate([
        total_gpcr_log10,
        total_gprot_log10,
        total_lig_log10,
        total_all_log10
    ])
})

# Append normalized mutation fractions
for metric in ['Trunk', 'Branch', 'Private']:
    data = pd.concat([
        data,
        pd.DataFrame({
            'Metric': [metric] * (
                len(genes_gpcr_filt[metric]) +
                len(genes_gprot_filt[metric]) +
                len(genes_lig_filt[metric]) +
                len(genes_all_filt[metric])
            ),
            'Gene Type': ['gpcr'] * len(genes_gpcr_filt[metric]) +
                         ['gprot'] * len(genes_gprot_filt[metric]) +
                         ['ligand'] * len(genes_lig_filt[metric]) +
                         ['all_genes'] * len(genes_all_filt[metric]),
            'Value': np.concatenate([
                genes_gpcr_filt[metric],
                genes_gprot_filt[metric],
                genes_lig_filt[metric],
                genes_all_filt[metric]
            ])
        })
    ])

# Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6), sharey=False)

# Colors
palette = {
    'gpcr': 'white',
    'gprot': 'coral',
    'ligand': '#69b3a2',
    'all_genes': 'darkgray'
}

# Left panel: total mutation counts
sns.boxplot(
    data=data.query("Metric == 'log10 Total'"),
    x='Gene Type',
    y='Value',
    palette=palette,
    ax=ax1,
)
ax1.set_title('Mutation Burden (log10 Total)', fontsize=16)
ax1.set_ylabel('Log10 Mutation Count')
ax1.set_xlabel('')
ax1.spines[['right', 'top']].set_visible(False)
ax1.tick_params(labelsize=12)

# Right panel: normalized fractions
sns.boxplot(
    data=data.query("Metric != 'log10 Total'"),
    x='Metric',
    y='Value',
    hue='Gene Type',
    palette=palette,
    ax=ax2,
)
ax2.set_title('Mutation Distribution in Phylogeny', fontsize=16)
ax2.set_ylabel('Proportion of Total Mutations')
ax2.set_xlabel('')
ax2.spines[['right', 'top']].set_visible(False)
ax2.tick_params(labelsize=12)
ax2.legend(title='Gene Type', fontsize=12)

plt.tight_layout()
plt.show()

# %%
from itertools import combinations
import numpy as np
import pandas as pd

def compute_jaccards(sub_df):
    # Get unique patients per gene, filtered to GPCR genes
    patients_per_gene = (
        sub_df.groupby('gene')['patient']
        .unique()
        .loc[lambda x: x.index.isin(gpcrs_genes)]
    )
    genes = patients_per_gene.index

    # Initialize Jaccard matrix
    jaccard_matrix = pd.DataFrame(
        np.eye(len(genes)), index=genes, columns=genes
    )

    for g1, g2 in combinations(genes, 2):
        set1, set2 = set(patients_per_gene[g1]), set(patients_per_gene[g2])
        union = set1 | set2
        sim = len(set1 & set2) / len(union) if union else 0
        jaccard_matrix.at[g1, g2] = sim
        jaccard_matrix.at[g2, g1] = sim

    # Flatten matrix
    jaccard = jaccard_matrix.stack()

    # Ligand-receptor Jaccard values
    lr_pairs = gpcrs_lr.set_index(['ligand', 'receptor']).index
    jaccard_lr = jaccard.loc[lr_pairs.intersection(jaccard.index)]

    # G-protein Jaccard values
    jaccard_gprot = []

    for gpcr in gprots_couplings.index.intersection(jaccard_matrix.index):
        interactors = jaccard_matrix.index.intersection(gprots_couplings.loc[gpcr])
        values = jaccard_matrix.loc[gpcr, interactors].reset_index()
        values.columns = ['interactor', 'value']
        values['gpcr'] = gpcr
        jaccard_gprot.append(values)

    jaccard_gprot = (
        pd.concat(jaccard_gprot)
        .set_index(['gpcr', 'interactor'])['value']
    )

    return jaccard_lr, jaccard_gprot

jaccard_lr_trunk, jaccard_gprot_trunk = compute_jaccards(df[df['when'].isin(['Trunk'])])
jaccard_lr_branch, jaccard_gprot_branch = compute_jaccards(df[df['when'].isin(['Trunk', 'Branch'])])
jaccard_lr_private, jaccard_gprot_private = compute_jaccards(df)

# %%
from scipy.stats import fisher_exact

def fisher_test(jaccard_lr, jaccard_gprot, label=""):
    table = [
        [(jaccard_lr > 0).sum(), (jaccard_lr == 0).sum()],
        [(jaccard_gprot > 0).sum(), (jaccard_gprot == 0).sum()]
    ]
    oddsratio, pval = fisher_exact(table)
    print(f"{label} → Odds ratio: {oddsratio:.3f}, p-value: {pval:.3f}")

# Run tests
fisher_test(jaccard_lr_trunk, jaccard_gprot_trunk, label="Trunk")
fisher_test(jaccard_lr_branch, jaccard_gprot_branch, label="Branch")
fisher_test(jaccard_lr_private, jaccard_gprot_private, label="Private")
# Out:
# Trunk → Odds ratio: 1.238, p-value: 0.268
# Branch → Odds ratio: 1.322, p-value: 0.085
# Private → Odds ratio: 1.560, p-value: 0.000

# %%
from scipy.stats import pearsonr

n_values = ncoev_jaccard.set_index(['gpcr', 'interactor'])['value']
n_values_gprot = n_values.loc[jaccard_gprot_private.index.intersection(n_values.index)]
pearsonr(jaccard_gprot_private.loc[n_values_gprot.index], n_values_gprot.loc[n_values_gprot.index])
# Out:
# PearsonRResult(statistic=-0.07644842511229723, pvalue=0.03222228252344315)

# %%
jaccard_gprot_private.loc[n_values_gprot.index].loc['ADORA1']
# Out:
# interactor
# GNA15    0.0
# GNAI1    0.0
# GNAI3    0.0
# GNAO1    0.0
# GNAZ     0.0
# Name: value, dtype: float64

# %%
ncoev_jaccard.query('interactor_type == "G-Protein"').head(10)
# Out:
#       gpcr interactor interactor_type    condition     value       tissue  \
# 0   ADORA1      GNA15       G-Protein  Coevolution  0.726708  Coevolution
# 1   ADORA1      GNAO1       G-Protein  Coevolution  0.176856  Coevolution
# 2   ADORA1      GNAI1       G-Protein  Coevolution  0.372093  Coevolution
# 3   ADORA1      GNAI3       G-Protein  Coevolution  0.254762  Coevolution
# 4   ADORA1       GNAZ       G-Protein  Coevolution  0.755435  Coevolution
# 5  ADORA2A      GNA15       G-Protein  Coevolution  0.692308  Coevolution
# 6  ADORA2A       GNAS       G-Protein  Coevolution  0.469466  Coevolution
# 7  ADORA2A      GNA14       G-Protein  Coevolution  0.235556  Coevolution
# 8  ADORA2A       GNAL       G-Protein  Coevolution  0.644550  Coevolution
# 9  ADORA2A       GNAQ       G-Protein  Coevolution  0.290698  Coevolution
#
#   value_type
# 0    jaccard
# 1    jaccard
# 2    jaccard
# 3    jaccard
# 4    jaccard
# 5    jaccard
# 6    jaccard
# 7    jaccard
# 8    jaccard
# ...

# %%
from scipy.stats import pearsonr

n_values = ncoev_jaccard.set_index(['gpcr', 'interactor'])['value']
n_values = n_values.swaplevel().rename_axis(index=['gene', 'gene'])
jaccard_lr_private.index.isin(n_values.index).sum()
n_values_lr = n_values.loc[jaccard_lr_private.index.intersection(n_values.index)]
pearsonr(jaccard_lr_private.loc[n_values_lr.index], n_values_lr.loc[n_values_lr.index])
# Out:
# PearsonRResult(statistic=-0.06948360016103522, pvalue=0.0333541857015608)

# %%
jaccard_gprot_private
# Out:
# gpcr       interactor
# ADCYAP1R1  GNA14         0.062500
#            GNAL          0.000000
#            GNAQ          0.034483
#            GNAS          0.093750
# ADORA1     GNA15         0.000000
#                            ...
# VIPR1      GNAI2         0.000000
#            GNAO1         0.000000
#            GNAQ          0.000000
#            GNAS          0.016667
#            GNAZ          0.000000
# Name: value, Length: 801, dtype: float64

# %%
plt.scatter(jaccard_gprot_private.loc[n_values_gprot.index], n_values_gprot.loc[n_values_gprot.index])
plt.xlim(0.005, 0.28)
# Out:
# (0.005, 0.28)

# %%
ncoev_jaccard.set_index(['gpcr', 'interactor'])['value']

# %%
jaccard_lr_private[::100]
# Out:
# gene     gene
# DAG1     CELSR3    0.081081
# CX3CL1   CX3CR1    0.000000
# SLC17A6  GRM8      0.000000
# ALOX5    GPR17     0.000000
# PTGES2   PTGER2    0.000000
# SLC6A3   DRD1      0.095238
# WNT3     FZD8      0.000000
# WNT9A    FZD9      0.166667
# GLUL     GRM6      0.000000
# TH       ADRB3     0.000000
# dtype: float64

# %%
jaccard_gprot_private.index.isin(n_values.index).sum()
# Out:
# 785

# %%
jaccard_lr_private.index.isin(n_values.index).sum()
# Out:
# 0

# %%
from scipy.stats import mannwhitneyu

# Run tests
res_all = mannwhitneyu(jaccard_lr_all, jaccard_gprot_all)
res_trunk = mannwhitneyu(jaccard_lr_trunk, jaccard_gprot_trunk)
res_branch = mannwhitneyu(jaccard_lr_branch, jaccard_gprot_branch)
res_private = mannwhitneyu(jaccard_lr_private, jaccard_gprot_private)

# Print formatted results
print("Mann–Whitney U Test Results:")
print(f"Trunk     → U = {res_trunk.statistic:.3f}, p = {res_trunk.pvalue:.3e}")
print(f"Branch    → U = {res_branch.statistic:.3f}, p = {res_branch.pvalue:.3e}")
print(f"Private   → U = {res_private.statistic:.3f}, p = {res_private.pvalue:.3e}")
# Out:
# Mann–Whitney U Test Results:
# Trunk     → U = 135405.000, p = 2.204e-01
# Branch    → U = 243275.500, p = 5.531e-02
# Private   → U = 434911.000, p = 3.001e-06

# %%
# Combine Jaccard data into a long-format DataFrame
all_data = []

# Add data from the 'Trunk' condition
for score in jaccard_lr_trunk:
    all_data.append({'value': score, 'interactor_type': 'Ligand', 'condition': 'Trunk'})
for score in jaccard_gprot_trunk:
    all_data.append({'value': score, 'interactor_type': 'G-Protein', 'condition': 'Trunk'})

# Add data from the 'Branch' condition
for score in jaccard_lr_branch:
    all_data.append({'value': score, 'interactor_type': 'Ligand', 'condition': 'Branch'})
for score in jaccard_gprot_branch:
    all_data.append({'value': score, 'interactor_type': 'G-Protein', 'condition': 'Branch'})

# Add data from the 'Private' condition
for score in jaccard_lr_private:
    all_data.append({'value': score, 'interactor_type': 'Ligand', 'condition': 'Private'})
for score in jaccard_gprot_private:
    all_data.append({'value': score, 'interactor_type': 'G-Protein', 'condition': 'Private'})

# Convert the combined data into a DataFrame
df_jaccard = pd.DataFrame(all_data)

# %%
def plot_cdf_with_ks(data, condition, ax, color_ligand, color_gpcr):
    fs = 18

    # Set ylim and xlim based on condition
    ax.set_ylim(0.67, 1.)
    
    if condition == "Private":
        ax.set_xlim(-0.01, 0.5)
        arrow_width = 0.01  # half width
        ax.set_xticks([0, 0.25, 0.5])

    else:
        ax.set_xlim(-0.01, 1)
        arrow_width = 0.02  # default width
        ax.set_xticks([0, 0.25, 0.5, 0.75, 1.00])

    # Filter data for the given condition
    df_condition = data[data['condition'] == condition]
    ligand_values = df_condition[df_condition['interactor_type'] == 'Ligand']['value']
    gpcr_values = df_condition[df_condition['interactor_type'] == 'G-Protein']['value']
    
    # KS test
    ks_stat, p_value = ks_2samp(ligand_values, gpcr_values)

    # ECDF plots
    sns.ecdfplot(ligand_values, ax=ax, color=color_ligand, label='Ligand', linewidth=3, zorder=2)
    sns.ecdfplot(gpcr_values, ax=ax, color=color_gpcr, label='G-Protein', linewidth=3, zorder=1)

    # D-statistic logic
    cdf_ligand = np.sort(ligand_values)
    cdf_gpcr = np.sort(gpcr_values)
    all_values = np.sort(np.unique(np.concatenate((cdf_ligand, cdf_gpcr))))
    cdf_ligand_y = np.searchsorted(cdf_ligand, all_values, side='right') / len(cdf_ligand)
    cdf_gpcr_y = np.searchsorted(cdf_gpcr, all_values, side='right') / len(cdf_gpcr)
    max_diff_index = np.argmax(np.abs(cdf_ligand_y - cdf_gpcr_y))

    x_max_diff = all_values[max_diff_index]
    y1_max_diff = cdf_ligand_y[max_diff_index]
    y2_max_diff = cdf_gpcr_y[max_diff_index]
    midpoint_y = (y1_max_diff + y2_max_diff) / 2

    # Vertical D-statistic line and arrows
    ax.vlines(x_max_diff, y1_max_diff, y2_max_diff, color='k', linestyle='-', lw=2)
    ax.arrow(x_max_diff, y1_max_diff, 0, y2_max_diff - y1_max_diff, 
             color='k', linestyle='-', lw=2, head_width=arrow_width, head_length=0.02, length_includes_head=True, zorder=10)
    ax.arrow(x_max_diff, y2_max_diff, 0, y1_max_diff - y2_max_diff, 
             color='k', linestyle='-', lw=2, head_width=arrow_width, head_length=0.02, length_includes_head=True, zorder=10)

    # Annotation with KS stat
    text_object = ax.text(
        0.55, 0.85,
        f'D = {ks_stat:.2f}\np = {p_value:.1e}',
        fontsize=fs - 2, ha='left', va='center',
        transform=ax.transAxes,
    )

    text_x, text_y = text_object.get_position()
    max_diff_axis_rel = ax.transData.transform((x_max_diff, midpoint_y))
    max_diff_axis_rel_x, max_diff_axis_rel_y = ax.transAxes.inverted().transform(max_diff_axis_rel)

    direction_x = max_diff_axis_rel_x - text_x
    direction_y = max_diff_axis_rel_y - text_y

    offset_x = direction_x * 0.95
    offset_y = direction_y * 0.95

    start_x = text_x + offset_x
    start_y = text_y + offset_y
    end_x = max_diff_axis_rel_x - offset_x
    end_y = max_diff_axis_rel_y - offset_y

    ax.plot([start_x, end_x], [start_y, end_y], color='k', lw=1, linestyle='-', zorder=9, transform=ax.transAxes)

    # Axis labels and legend
    ax.set_title(f'{condition}', fontsize=fs)
    ax.set_xlabel('Jaccard Index', fontsize=fs)
    ax.set_ylabel('Cumulative Probability', fontsize=fs)
    ax.tick_params(labelsize=fs)
    ax.legend(fontsize=fs, loc='lower right')
    ax.grid(False)
    
    # Remove top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

# Create a mosaic of subplots
layout = [
    ['A', 'top_center', 'top_right'],
]
fig = plt.figure(figsize=(19, 6))

# Create a subplot mosaic with 1x3 grid layout
fig = plt.figure(figsize=(19, 6))

# Create the axes using the subplot mosaic
axes = fig.subplot_mosaic(
    """
    ABC
    """
)

# Plot for each condition
for i, condition in enumerate(df_jaccard['condition'].unique()):
    plot_cdf_with_ks(df_jaccard, condition, axes[chr(65 + i)], tcolor, lightgray)

# Remove legends from the first two axes
for ax in axes['A'], axes['B']:
    ax.legend_.remove()

# Save the figure
plt.savefig('/home/lnemati/pathway_crosstalk/results/figures/gpcrs/gpcrs_tumor_coevolution.png', bbox_inches='tight', dpi=300)
plt.savefig('/home/lnemati/pathway_crosstalk/results/figures/gpcrs/gpcrs_tumor_coevolution.pdf', bbox_inches='tight', dpi=300)

# Show the plot
plt.show()

# %%
#fig_to_panels(fig, axes, output_dir='/home/lnemati/pathway_crosstalk/results/figures/gpcrs/')
# Out:
# Saved panel 'Trunk' to /home/lnemati/pathway_crosstalk/results/figures/gpcrs/trunk
# Saved panel 'Branch' to /home/lnemati/pathway_crosstalk/results/figures/gpcrs/branch
# Saved panel 'Private' to /home/lnemati/pathway_crosstalk/results/figures/gpcrs/private

# %%
pd.DataFrame({
        'Score': list(groups['LR']) + list(groups['GProt']),
        'Group': ['LR'] * len(groups['LR']) + ['GProt'] * len(groups['GProt'])
    })

# %%
print(sum(jaccard_lr_all > 0) / jaccard_lr_all.shape[0])
print(sum((jaccard_gprot_all > 0) / jaccard_gprot_all.shape[0]))
# Out:
# 0.3174442190669371
# 0.24387464387464466

# %%
print(sum(jaccard_lr_trunk > 0) / jaccard_lr_trunk.shape[0])
print(sum((jaccard_gprot_trunk > 0) / jaccard_gprot_trunk.shape[0]))
# Out:
# 0.14418604651162792
# 0.11291963377416055

# %%
all_fracs = genes.groupby('when')['count'].sum()
all_fracs = all_fracs / all_fracs.sum()

gprots_fracs = genes[genes.gene.isin(gprots)].groupby('when')['count'].sum()
gprots_fracs = gprots_fracs / gprots_fracs.sum()

gpcrs_fracs = genes[genes.gene.isin(gpcrs)].groupby('when')['count'].sum()
gpcrs_fracs = gpcrs_fracs / gpcrs_fracs.sum()

lig_fracs = genes[genes.gene.isin(gpcrs_ligands)].groupby('when')['count'].sum()
lig_fracs = lig_fracs / lig_fracs.sum()

# %%
genes.groupby('when')['count'].count()
# Out:
# when
# Branch     11688
# Private    17598
# Trunk      14624
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Desired order of 'when'
when_order = ['Trunk', 'Branch', 'Private']

# Count-based fractions (not sums)
all_fracs = genes.groupby('when')['count'].sum()
all_fracs = all_fracs / all_fracs.sum()

gprots_fracs = genes[genes.gene.isin(gprots)].groupby('when')['count'].sum()
gprots_fracs = gprots_fracs / gprots_fracs.sum()

gpcrs_fracs = genes[genes.gene.isin(gpcrs)].groupby('when')['count'].sum()
gpcrs_fracs = gpcrs_fracs / gpcrs_fracs.sum()

lig_fracs = genes[genes.gene.isin(gpcrs_ligands)].groupby('when')['count'].sum()
lig_fracs = lig_fracs / lig_fracs.sum()

# Combine into one DataFrame and enforce 'when' order
df = pd.concat([
    all_fracs.rename('All Genes'),
    gprots_fracs.rename('G-Proteins'),
    gpcrs_fracs.rename('GPCRs'),
    lig_fracs.rename('GPCR Ligands')
], axis=1).reindex(when_order)

# Transpose so bars are categories
df = df.T.fillna(0)

# Plot as stacked bar chart
ax = df.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    width=1.,  # Full width, removes horizontal whitespace
    alpha=0.9
)

plt.title('Distribution of Expression Across Timepoints')
plt.xlabel('Gene Category')
plt.ylabel('Fraction')
plt.legend(title='When', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Collect data into a list of dictionaries
data = []

for label, j_lr, j_gp in [
    ("All", jaccard_lr_all, jaccard_gprot_all),
    ("Trunk", jaccard_lr_trunk, jaccard_gprot_trunk),
    ("Branch", jaccard_lr_branch, jaccard_gprot_branch),
    ("Private", jaccard_lr_private, jaccard_gprot_private),
]:
    data.append({'context': label, 'group': 'Ligand - GPCR', 'value': (j_lr > 0).mean()})
    data.append({'context': label, 'group': 'G-Protein - GPCR', 'value': (j_gp > 0).mean()})

# Create DataFrame
plot_df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(6, 4))
sns.barplot(data=plot_df, x='context', y='value', hue='group')

# Title and labels
plt.title("Proportion of Gene Pairs Co-Mutated in at Least One Patient")
plt.ylabel("Proportion")
plt.ylim(0, 0.25)

plt.tight_layout()
plt.show()

# %%
from scipy.stats import mannwhitneyu, ks_2samp

# Mann-Whitney U Test
print("Mann-Whitney U Test Results:")

# Trunk
stat_trunk, pval_trunk = mannwhitneyu(jaccard_lr_trunk, jaccard_gprot_trunk)
print(f"Trunk: U-statistic = {stat_trunk}, p-value = {pval_trunk}")

# Branch
stat_branch, pval_branch = mannwhitneyu(jaccard_lr_branch, jaccard_gprot_branch)
print(f"Branch: U-statistic = {stat_branch}, p-value = {pval_branch}")

# Private
stat_private, pval_private = mannwhitneyu(jaccard_lr_private, jaccard_gprot_private)
print(f"Private: U-statistic = {stat_private}, p-value = {pval_private}")

# Kolmogorov-Smirnov Test
print("\nKolmogorov-Smirnov Test Results:")

# Trunk
ks_stat_trunk, ks_pval_trunk = ks_2samp(jaccard_lr_trunk, jaccard_gprot_trunk)
print(f"Trunk: KS-statistic = {ks_stat_trunk}, p-value = {ks_pval_trunk}")

# Branch
ks_stat_branch, ks_pval_branch = ks_2samp(jaccard_lr_branch, jaccard_gprot_branch)
print(f"Branch: KS-statistic = {ks_stat_branch}, p-value = {ks_pval_branch}")

# Private
ks_stat_private, ks_pval_private = ks_2samp(jaccard_lr_private, jaccard_gprot_private)
print(f"Private: KS-statistic = {ks_stat_private}, p-value = {ks_pval_private}")
# Out:
# Mann-Whitney U Test Results:
# Trunk: U-statistic = 76884.5, p-value = 0.36491619125957786
# Branch: U-statistic = 40575.0, p-value = 0.2788101600169932
# Private: U-statistic = 473149.5, p-value = 2.38446892334598e-06
#
# Kolmogorov-Smirnov Test Results:
# Trunk: KS-statistic = 0.026081145584725535, p-value = 0.9985988277168166
# Branch: KS-statistic = 0.03402512702545565, p-value = 0.99708433115222
# Private: KS-statistic = 0.07697450424929178, p-value = 0.008904168820604866

# %%
sns.violinplot(jaccard_lr_private)
sns.violinplot(jaccard_gprot_private)
# Out:
# <Axes: ylabel='value'>

# %%
plt.plot(jaccard_lr_trunk.sort_values().values)
plt.plot(jaccard_gprot_trunk.sort_values().values)

# %%
# Count of positives (>0) for each 'when' category
lr_positives = [
    (jaccard_lr_trunk > 0).sum(),
    (jaccard_lr_branch > 0).sum(),
    (jaccard_lr_private > 0).sum()
]

gprot_positives = [
    (jaccard_gprot_trunk > 0).sum(),
    (jaccard_gprot_branch > 0).sum(),
    (jaccard_gprot_private > 0).sum()
]

# Optional: wrap them as named Series for clarity
contexts = ['Trunk', 'Branch', 'Private']
lr_vector = pd.Series(lr_positives, index=contexts, name='lr')
gprot_vector = pd.Series(gprot_positives, index=contexts, name='gprot')

print("Ligand–Receptor Positive Counts:")
print(lr_vector / lr_vector.sum())

print("\nG Protein Positive Counts:")
print(gprot_vector / gprot_vector.sum())
# Out:
# Ligand–Receptor Positive Counts:
# Trunk      0.238636
# Branch     0.096591
# Private    0.664773
# Name: lr, dtype: float64
#
# G Protein Positive Counts:
# Trunk      0.278049
# Branch     0.151220
# Private    0.570732
# Name: gprot, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Proportions of positives (>0) for each category
lr_proportion = lr_vector / lr_vector.sum()
gprot_proportion = gprot_vector / gprot_vector.sum()

# Combine both series into one DataFrame for easier plotting
plot_data = pd.DataFrame({
    'Proportion': pd.concat([lr_proportion, gprot_proportion]),
    'Group': ['lr'] * len(lr_proportion) + ['gprot'] * len(gprot_proportion),
    'Context': ['Trunk', 'Branch', 'Private'] * 2
})

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(data=plot_data, x='Context', y='Proportion', hue='Group')
plt.title("Proportion of Positive Jaccard Values by Group and Context")
plt.ylabel("Proportion of Positives (> 0)")
plt.tight_layout()
plt.show()

# %%
mannwhitneyu(jaccard_lr, jaccard_gprot)
# Out:
# MannwhitneyuResult(statistic=388811.5, pvalue=6.144207544239558e-08)

# %%
# Out:
# 0.1357403355855398

# %%
#sns.ecdfplot(jaccard_lr, lw=3, color='magenta')
#sns.ecdfplot(jaccard_gprot, lw=3, color=lightgray)
# Out:
# <Axes: xlabel='value', ylabel='Proportion'>

# %%
df
# Out:
#         mutation      patient     when    gene   gpcr  gprot  ligand
# BRAF     p.V600E  p001_PCRC01    Trunk    BRAF  False  False   False
# APC     p.R1432X  p001_PCRC03    Trunk     APC  False  False   False
# KRAS      p.G12V  p001_PCRC03    Trunk    KRAS  False  False   False
# KRAS      p.G13D    p002_PMME    Trunk    KRAS  False  False   False
# BRAF     p.H574Q    p002_PMME    Trunk    BRAF  False  False   False
# ...          ...          ...      ...     ...    ...    ...     ...
# SLAMF7   p.E257D     p168_P90  Private  SLAMF7  False  False   False
# AJAP1    p.V200I     p168_P90  Private   AJAP1  False  False   False
# BTRC     p.L210L     p168_P90  Private    BTRC  False  False   False
# DUSP27   p.A321T     p168_P90  Private  DUSP27  False  False   False
# PASD1    p.L148V     p168_P90  Private   PASD1  False  False   False
#
# [86883 rows x 7 columns]

# %%
df.index = (df['patient'] + '_' + df['gene'])
df['unique_id'] = (df['patient'] + '_' + df['gene'])

# %%
counts = df.groupby(['unique_id', 'when']).size().reset_index(name='count')
counts = counts.sort_values(by='count', ascending=False)
counts['patient'] = counts['unique_id'].str.split('_').apply(lambda x: '_'.join(x[:-1]))
counts['gene'] = counts['unique_id'].str.split('_').apply(lambda x: '_'.join(x[-1:]))

counts['ccc'] = False
counts.loc[counts.gene.isin(lr), 'ccc'] = True

# %%
counts
# Out:
#                          unique_id     when  count      patient  \
# 30168             p113_case26_MUC4    Trunk     78  p113_case26
# 21762             p113_case01_MUC4    Trunk     73  p113_case01
# 4744               p011_MSI-H2_FLG    Trunk     48  p011_MSI-H2
# 5645             p011_MSI-H2_MUC16    Trunk     35  p011_MSI-H2
# 73055                p164_P2_MUC3A   Branch     27      p164_P2
# ...                            ...      ...    ...          ...
# 27593            p113_case14_RP1L1  Private      1  p113_case14
# 27592     p113_case14_RP11-57A19.3  Private      1  p113_case14
# 27591  p113_case14_RP11-1286E23.17    Trunk      1  p113_case14
# 27590              p113_case14_RP1  Private      1  p113_case14
# 79113               p168_P90_ZMAT1    Trunk      1     p168_P90
#
#                   gene    ccc
# 30168             MUC4  False
# 21762             MUC4  False
# 4744               FLG  False
# 5645             MUC16  False
# 73055            MUC3A  False
# ...

# %%
genes = counts.groupby(['gene', 'when'])['count'].sum().to_frame()

# %%
genes['gene'] = genes.index.get_level_values(0)
genes['when'] = genes.index.get_level_values(1)
genes.index = range(len(genes))

# %%
# Group by 'gene' and calculate the total counts for each gene
total_counts = genes.groupby('gene')['count'].sum()

# Sort genes by total count in descending order
genes = genes.set_index('gene').loc[total_counts.sort_values(ascending=False).index].reset_index()

# %%
genes
# Out:
#            gene  count     when
# 0          MUC4     20   Branch
# 1          MUC4    164  Private
# 2          MUC4    203    Trunk
# 3          TP53     58   Branch
# 4          TP53     71  Private
# ...         ...    ...      ...
# 33540    FAM29A      1   Branch
# 33541    FAM26F      1  Private
# 33542     SYT17      1    Trunk
# 33543      SYT2      1  Private
# 33544  MAP1LC3C      1  Private
#
# [33545 rows x 3 columns]

# %%
## Init df for test results
results = pd.DataFrame(columns=['auroc', 'pval'])

genes_pivot = genes.pivot(index='gene', columns='when', values='count').fillna(0)
genes_pivot = genes_pivot.loc[total_counts.sort_values(ascending=False).index]

genes_pivot_gpcr = genes_pivot.loc[genes_pivot.index.isin(gpcrs)]
total_gpcr_log10 = np.log10(genes_pivot_gpcr.sum(axis=1))

genes_pivot_gprot = genes_pivot.loc[genes_pivot.index.isin(gprots)]
total_gprot_log10 = np.log10(genes_pivot_gprot.sum(axis=1))

genes_pivot_lig = genes_pivot.loc[genes_pivot.index.isin(ligands)]
total_lig_log10 = np.log10(genes_pivot_lig.sum(axis=1))

# Perform Mann-Whitney U test on log10 transformed total values, compare G-Prots and Ligands
result = mannwhitneyu(total_lig_log10, total_gprot_log10)

# Store AUROC and p-value for log10 Total
results.loc['log10 Total', 'auroc'] = result.statistic / (total_lig_log10.shape[0] * total_gprot_log10.shape[0])
results.loc['log10 Total', 'pval'] = result.pvalue

# %%
# Normalize Trunk, Branch, and Private by Total for CCC and Other Genes
genes_gpcr_norm = genes_pivot_gpcr.T.div(genes_pivot_gpcr.sum(axis=1)).T
genes_gprot_norm = genes_pivot_gprot.T.div(genes_pivot_gprot.sum(axis=1)).T
genes_lig_norm = genes_pivot_lig.T.div(genes_pivot_lig.sum(axis=1)).T

# Perform comparisons for Trunk, Branch, and Private
for col in genes_pivot.columns:
    result = mannwhitneyu(genes_lig_norm[col], genes_gprot_norm[col])
    results.loc[col, 'auroc'] = result.statistic / (genes_lig_norm.shape[0] * genes_gprot_norm.shape[0])
    results.loc[col, 'pval'] = result.pvalue
    
# Apply multiple testing correction
results['pval_adj'] = false_discovery_control(results.pval.astype(float).values)

results = results.loc[['log10 Total', 'Trunk', 'Branch', 'Private']]
#results.to_csv('/home/lnemati/pathway_crosstalk/results/coevolution/cosmic/test_results.csv')

# %%
results
# Out:
#                 auroc      pval  pval_adj
# log10 Total  0.394772  0.196012  0.371869
# Trunk        0.584915  0.278901  0.371869
# Branch       0.392774  0.145914  0.371869
# Private      0.477855  0.786871  0.786871

# %%
# Boxplots

fs=18

fig, ax = plt.subplot_mosaic(
    '''
    ABB
    ''',
    figsize=(15,9)
)

# Melt data for plotting
data = pd.DataFrame({
    'Comparison': (['log10 Total'] * len(total_gpcr_log10) + ['log10 Total'] * len(total_gprot_log10) + ['log10 Total'] * len(total_lig_log10) +
                   ['Trunk'] * len(genes_gpcr_norm['Trunk']) + ['Trunk'] * len(genes_gprot_norm['Trunk']) + ['Trunk'] * len(genes_lig_norm['Trunk']) +
                   ['Branch'] * len(genes_gpcr_norm['Branch']) + ['Branch'] * len(genes_gprot_norm['Branch']) + ['Branch'] * len(genes_lig_norm['Branch']) +
                   ['Private'] * len(genes_gpcr_norm['Private']) + ['Private'] * len(genes_gprot_norm['Private']) + ['Private'] * len(genes_lig_norm['Private'])),
    'Gene Type': (['gpcr'] * len(total_gpcr_log10) + ['gprot'] * len(total_gprot_log10) + ['ligand'] * len(total_lig_log10) +
                  ['gpcr'] * len(genes_gpcr_norm['Trunk']) + ['gprot'] * len(genes_gprot_norm['Trunk']) + ['ligand'] * len(genes_lig_norm['Trunk']) +
                  ['gpcr'] * len(genes_gpcr_norm['Branch']) + ['gprot'] * len(genes_gprot_norm['Branch']) + ['ligand'] * len(genes_lig_norm['Branch']) +
                  ['gpcr'] * len(genes_gpcr_norm['Private']) + ['gprot'] * len(genes_gprot_norm['Private']) + ['ligand'] * len(genes_lig_norm['Private'])),
    'Value': np.concatenate([total_gpcr_log10, total_gprot_log10, total_lig_log10,
                             genes_gpcr_norm['Trunk'], genes_gprot_norm['Trunk'], genes_lig_norm['Trunk'],
                             genes_gpcr_norm['Branch'], genes_gprot_norm['Branch'], genes_lig_norm['Branch'],
                             genes_gpcr_norm['Private'], genes_gprot_norm['Private'], genes_lig_norm['Private']])
})


counts = data.query('Comparison == "log10 Total"')
fracs = data.query('Comparison != "log10 Total"')

# Total counts
sns.boxplot(
    x='Gene Type',
    y='Value',
    hue='Gene Type',
    data=counts,
    palette={'gpcr': 'white', 'gprot': lightgray, 'ligand': tcolor},
    ax=ax['A']
)

# Trunk, Brach, Private
sns.boxplot(
    x='Comparison',
    y='Value',
    hue='Gene Type',
    data=fracs,
    palette={'gpcr': 'white', 'gprot': lightgray, 'ligand': tcolor},
    ax=ax['B']
)
  
ax['A'].set_title('Number of Mutations', fontsize=fs)
#ax['A'].set_xlabel("Gene Type")
ax['A'].set_xlabel("", fontsize=fs)
ax['A'].set_ylabel("Counts (Log10)", fontsize=fs)
ax['A'].set_ylim(-0.004,2.1)
ax['A'].set_yticks([0,1,2])

ax['B'].set_title('Position in Phylogenetic Tree', fontsize=fs)
#ax['B'].set_xlabel("Phylogenetic Tree Position")
ax['B'].set_xlabel("", fontsize=fs)
ax['B'].set_ylabel("Proportion", fontsize=fs)
ax['B'].set_ylim(-0.002,1.05)
ax['B'].set_yticks([0,0.5,1])

for key in ax:
    ax[key].spines[['right', 'top']].set_visible(False)
    ax[key].tick_params(labelsize=fs)
    
# Add significance bars
for i, (comparison, row) in enumerate(results.iterrows()):
    if comparison == "log10 Total":
        which_ax = ax['A']
        x_positions = [1, 2]  # Positions of 'CCC Genes' and 'Other Genes'
    else:
        which_ax = ax['B']
        x_positions = [i - 1]  # Positions corresponding to 'Trunk', 'Branch', 'Private'

    if row['pval_adj'] < 0.05:
        lims = which_ax.get_ylim()
        yrange = lims[1] - lims[0]
        y = lims[0] + 0.92 * yrange  # Position of the horizontal bar

        if which_ax == ax['A']:
            # Horizontal line between gprots and ligands
            which_ax.plot([1, x_positions[1] + 0.2], [y, y], color='black')
            # Vertical segments
            which_ax.plot([1, 1], [y - 0.025 * yrange, y], color='black')
            which_ax.plot([x_positions[1] + 0.2, x_positions[1] + 0.2], [y - 0.025 * yrange, y], color='black')
            # Significance stars at the midpoint
            which_ax.text(1.5, y + 0.05, '*' * (1 + (row['pval_adj'] < 0.01) + (row['pval_adj'] < 0.001)),
                          ha='center', color='black', weight='bold')
        else:
            # Horizontal line above the single category
            which_ax.plot([x_positions[0] - 0.2, x_positions[0] + 0.2], [y, y], color='black')
            # Vertical segments
            which_ax.plot([x_positions[0] - 0.2, x_positions[0] - 0.2], [y - 0.025 * yrange, y], color='black')
            which_ax.plot([x_positions[0] + 0.2, x_positions[0] + 0.2], [y - 0.025 * yrange, y], color='black')
            # Significance stars directly above
            which_ax.text(x_positions[0], y + 0.05, '*' * (1 + (row['pval_adj'] < 0.01) + (row['pval_adj'] < 0.001)),
                          ha='center', color='black', weight='bold')

ax['B'].legend(title='Gene Type', fontsize=fs)

#plt.savefig('/home/lnemati/pathway_crosstalk/results/figures/tumor_coev/boxplots.pdf', bbox_inches='tight')
#plt.savefig('/home/lnemati/pathway_crosstalk/results/figures/tumor_coev/boxplots.png', bbox_inches='tight')

plt.show()

# %%
mannwhitneyu(genes_gprot_norm['Trunk'], genes_lig_norm['Trunk'])
# Out:
# MannwhitneyuResult(statistic=1246.5, pvalue=0.2789013922243583)

# %%
(genes_gprot_norm['Trunk'] > 0).value_counts()
# Out:
# Trunk
# False    7
# True     6
# Name: count, dtype: int64

# %%
(genes_lig_norm['Trunk'] > 0).value_counts()
# Out:
# Trunk
# True     126
# False    105
# Name: count, dtype: int64

# %%
results
# Out:
#                 auroc      pval  pval_adj
# log10 Total  0.394772  0.196012  0.371869
# Trunk        0.584915  0.278901  0.371869
# Branch       0.392774  0.145914  0.371869
# Private      0.477855  0.786871  0.786871
