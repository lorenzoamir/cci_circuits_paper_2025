# %%
import matplotlib.pyplot as plt
import pandas as pd
from itertools import product
import re

# Define colors
# Light version is obtained by setting alpha=0.5

ncolor  = '#00728eff' # solid dark
ncolor2 = '#00728e80' # alpha=0.5
lightncolor = '#7fb8c6ff' # solid light

tcolor  = '#ab3502ff'
tcolor2 = '#ab350280'
lighttcolor = '#d49980ff'

graycolor = '#4D4E4FFF'
graycolor2 ='#4d4e4f80'

lightgray = '#C8CAD4'

orangecolor = '#e69426'
orangecolor2 = '#e6942680'
lightorangecolor = '#f2c992ff'

# %%
drugs_df = pd.read_csv('/home/lnemati/pathway_crosstalk/results/crosstalk/all_ccc_complex_pairs/adj/motifs/tumor/drugs.csv')
drugs_df.head()
# Out:
#     gene                 drug                     action  \
# 0   EGFR            Cetuximab                 ['binder']
# 1  IL2RB  Denileukin diftitox                 ['ligand']
# 2    TNF           Etanercept  ['antibody', 'inhibitor']
# 3  PLAUR            Urokinase   ['inducer', 'modulator']
# 4  IL1R1             Anakinra             ['antagonist']
#
#                           approval  \
# 0                     ['approved']
# 1  ['approved', 'investigational']
# 2  ['approved', 'investigational']
# 3  ['approved', 'investigational']
# 4  ['approved', 'investigational']
#
#                                            hallmarks
# 0  ['HALLMARK_ALLOGRAFT_REJECTION', 'HALLMARK_API...
# 1  ['HALLMARK_ALLOGRAFT_REJECTION', 'HALLMARK_API...
# 2  ['HALLMARK_ALLOGRAFT_REJECTION', 'HALLMARK_APO...
# 3  ['HALLMARK_APICAL_SURFACE', 'HALLMARK_CHOLESTE...
# 4  ['HALLMARK_IL6_JAK_STAT3_SIGNALING', 'HALLMARK...

# %%
# Load cliques
tumor_cliques = pd.read_csv('/home/lnemati/pathway_crosstalk/results/crosstalk/all_ccc_complex_pairs/adj/motifs/tumor/motifs.csv')
tumor_cliques = tumor_cliques.query('Type in ["3_clique", "4_clique"]')
tumor_cliques['all_genes'] = tumor_cliques['Interaction'].apply(lambda x: re.split(r'[+_^&]', x))
tumor_cliques['int1'] = tumor_cliques['Interaction'].apply(lambda x: re.split(r'[+_^]', x.split('&')[0]))
tumor_cliques['int2'] = tumor_cliques['Interaction'].apply(lambda x: re.split(r'[+_^]', x.split('&')[1]))

# %% [markdown]
# # Drug Synergies

# %%
# --- 1. Load datasets ---
clique_drugs = pd.read_csv(
    '/home/lnemati/pathway_crosstalk/results/crosstalk/all_ccc_complex_pairs/adj/motifs/tumor/approved_drug_pairs.csv',
    index_col=0
)

synergies_anchor = pd.read_csv(
    '/home/lnemati/drug_synergies/only_synergistic_anchor_drugs.csv', index_col=0
)
synergies_matrix = pd.read_csv(
    '/home/lnemati/drug_synergies/only_synergistic_matrix_drugs.csv', index_col=0
)

all_matrix_unfiltered = pd.read_csv(
    '/home/lnemati/drug_synergies/processed_synergy_dataset_matrix_all_pairs_unfiltered.csv'
)
all_anchor_unfiltered = pd.read_csv(
    '/home/lnemati/drug_synergies/processed_synergy_dataset_anchor_all_pairs_unfiltered.csv'
)

gdsc_drugs = pd.read_csv('/home/lnemati/drug_synergies/GDSC_drugs.csv', index_col=0)
gdsc_drugs['HGCN_TARGETS'] = gdsc_drugs['HGCN_TARGETS'].str.split(',')

all_clique_genes = set([g for sublist in tumor_cliques['all_genes'] for g in eval(str(sublist))])

# --- 2. Create target mappings ---
drug_to_targets = gdsc_drugs.set_index('DRUG_NAME')['HGCN_TARGETS'].to_dict()
drugbank_to_targets = drugs_df.groupby('drug')['gene'].apply(list).to_dict()
# Out:
# /var/tmp/pbs.435919.pbs01/ipykernel_218152/3624542700.py:17: DtypeWarning: Columns (6,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_anchor_unfiltered = pd.read_csv(

# %%
import pandas as pd

# --- 1. Merge targets from GDSC + DrugBank ---
def merge_targets(drug_name, gdsc_mapping, db_mapping):
    """Return the combined list of targets from GDSC and DrugBank (deduplicated)."""
    gdsc_targets = gdsc_mapping.get(drug_name, [])
    db_targets = db_mapping.get(drug_name, [])
    return sorted(set(gdsc_targets + db_targets))  # keep order predictable

# --- 2. Prepare synergies dataset ---
def prepare_synergies(df, drug_col1, drug_col2, gdsc_map, db_map):
    """
    Add targets1/targets2, drop rows without targets, .
    df: input dataframe
    drug_col1/drug_col2: column names for the two drugs
    """
    df = df.copy()
    
    # Add DRUGBANK targets
    df['targets1'] = df[drug_col1].apply(lambda x: merge_targets(x, gdsc_map, db_map))
    df['targets2'] = df[drug_col2].apply(lambda x: merge_targets(x, gdsc_map, db_map))
    
    # Create ordered drug pair key to handle duplicates
    #df['pair'] = df.apply(lambda x: tuple(sorted([x[drug_col1], x[drug_col2]])), axis=1)
    df['pair'] = df.apply(lambda x: tuple([x[drug_col1], x[drug_col2]]), axis=1)

    # Drop exact duplicate pairs
    df = df.drop_duplicates(subset='pair').drop(columns='pair')
    
    # Only consider clique genes
    df['targets1'] = df['targets1'].apply(lambda x: [g for g in x if g in set(all_clique_genes)])
    df['targets2'] = df['targets2'].apply(lambda x: [g for g in x if g in set(all_clique_genes)])
    df = df[(df['targets1'].str.len() > 0) & (df['targets2'].str.len() > 0)]
    
    return df.rename(columns={drug_col1: 'drug1', drug_col2: 'drug2'})

# --- 4. Detect drug-clique interactions ---
def detect_clique_interactions(synergies_df, tumor_cliques):
    from itertools import product
    
    results = []
    for _, syn in synergies_df.iterrows():
        targets1 = set(syn.targets1)
        targets2 = set(syn.targets2)
        
        for _, clique_row in tumor_cliques.iterrows():
            genes1 = set(clique_row.int1)
            genes2 = set(clique_row.int2)
            
            # check one way
            subset1 = targets1 & genes1
            subset2 = targets2 & genes2

            # check the other way
            subset3 = targets1 & genes2
            subset4 = targets2 & genes1
            
            if subset1 and subset2:
                if subset1 != subset2: # exclude cases where it's the same genes in both interactions
                    results.append({
                        "interaction": clique_row.Interaction,
                        "drug1": syn.drug1,
                        "drug2": syn.drug2,
                        "targets1": subset1,
                        "targets2": subset2,
                    })
            if subset3 and subset4:
                if subset3 != subset4: # exclude cases where it's the same genes in both interactions
                    # if drug1 targets interaction 2 and drug2 targets interaction 1, switch them
                    results.append({
                        "interaction": clique_row.Interaction,
                        "drug1": syn.drug1,
                        "drug2": syn.drug2,
                        "targets1": subset4,
                        "targets2": subset3,
                    })
                
    df = pd.DataFrame(results).sort_values(by='interaction').reset_index(drop=True)
    
    # Create a unique string ID using interaction + sorted drugs
    unique_str_id = df.apply(
        lambda x: x['interaction'] + '_' + '_'.join(sorted([x['drug1'], x['drug2']])),
        axis=1
    )
    
    # Keep only the first occurrence of each unique ID
    df = df.loc[~unique_str_id.duplicated()].reset_index(drop=True)
    
    return df[['interaction', 'drug1', 'drug2', 'targets1', 'targets2']]
    
# --- 5. Run pipeline for filtered dataset ---
synergies_anchor_prepared = prepare_synergies(
    synergies_anchor, 'ANCHOR_NAME', 'LIBRARY_NAME', drug_to_targets, drugbank_to_targets
)
synergies_matrix_prepared = prepare_synergies(
    synergies_matrix, 'lib1_name', 'lib2_name', drug_to_targets, drugbank_to_targets
)
all_synergies_filtered = pd.concat([synergies_anchor_prepared, synergies_matrix_prepared], ignore_index=True)
all_detected_df = detect_clique_interactions(all_synergies_filtered, tumor_cliques)

# --- 6. Run pipeline for unfiltered dataset ---
all_anchor_unf_prepared = prepare_synergies(
    all_anchor_unfiltered, 'ANCHOR_NAME', 'LIBRARY_NAME', drug_to_targets, drugbank_to_targets
)
all_matrix_unf_prepared = prepare_synergies(
    all_matrix_unfiltered, 'lib1_name', 'lib2_name', drug_to_targets, drugbank_to_targets
)
all_synergies_unfiltered = pd.concat([all_anchor_unf_prepared, all_matrix_unf_prepared], ignore_index=True)
all_detectable_unfiltered_df = detect_clique_interactions(all_synergies_unfiltered, tumor_cliques)

# %%
all_detected_df
# Out:
#                              interaction        drug1         drug2  \
# 0       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB     Axitinib     Sorafenib
# 1       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib     Dasatinib
# 2        ITGA4_ITGB1+PLAUR&CD8A_CD8B+LCK  Ruxolitinib     Dasatinib
# 3  ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB  Ruxolitinib     Dasatinib
# 4  PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1    Sorafenib  Galunisertib
# 5              PDGFB+PDGFRB&PDGFB+PDGFRA     Axitinib     Sorafenib
# 6              PDGFB+PDGFRB&PDGFB+PDGFRA    Sorafenib     Dasatinib
#
#            targets1          targets2
# 0       {FLT1, KDR}  {PDGFRB, PDGFRA}
# 1       {FLT1, KDR}  {PDGFRB, PDGFRA}
# 2           {PLAUR}             {LCK}
# 3           {PLAUR}  {PDGFRB, PDGFRA}
# 4  {PDGFRB, PDGFRA}           {TGFB1}
# 5          {PDGFRB}          {PDGFRA}
# 6          {PDGFRB}          {PDGFRA}

# %%
all_detectable_unfiltered_df
# Out:
#                              interaction        drug1         drug2  \
# 0       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib     Dasatinib
# 1       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB     Axitinib     Sorafenib
# 2        ITGA4_ITGB1+PLAUR&CD8A_CD8B+LCK  Ruxolitinib     Dasatinib
# 3  ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB  Ruxolitinib     Dasatinib
# 4  ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB    Sorafenib   Ruxolitinib
# 5  PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1    Dasatinib  Galunisertib
# 6  PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1    Sorafenib  Galunisertib
# 7              PDGFB+PDGFRB&PDGFB+PDGFRA    Sorafenib     Dasatinib
# 8              PDGFB+PDGFRB&PDGFB+PDGFRA     Axitinib     Sorafenib
#
#            targets1          targets2
# 0       {FLT1, KDR}  {PDGFRB, PDGFRA}
# 1       {FLT1, KDR}  {PDGFRB, PDGFRA}
# 2           {PLAUR}             {LCK}
# 3           {PLAUR}  {PDGFRB, PDGFRA}
# 4           {PLAUR}  {PDGFRB, PDGFRA}
# 5  {PDGFRB, PDGFRA}           {TGFB1}
# ...

# %%
# Make sure both (drug1, drug2) and (drug2, drug1) are there

# Detectable pairs
mirror = all_detectable_unfiltered_df[['drug1', 'drug2']]
mirror.columns = ['drug2', 'drug1'] # invert

detectable_pairs = pd.concat([
    all_detectable_unfiltered_df[['drug1', 'drug2']],
    mirror
]).drop_duplicates().reset_index(drop=True)

# Detected pairs
mirror = all_detected_df[['drug1', 'drug2']]
mirror.columns = ['drug2', 'drug1'] # invert

detected_pairs = pd.concat([
    all_detected_df[['drug1', 'drug2']],
    mirror
]).drop_duplicates().reset_index(drop=True)

# Prepare drug columns
synergies_anchor['drug1'] = synergies_anchor['ANCHOR_NAME']
synergies_anchor['drug2'] = synergies_anchor['LIBRARY_NAME']
all_anchor_unfiltered['drug1'] = all_anchor_unfiltered['ANCHOR_NAME']
all_anchor_unfiltered['drug2'] = all_anchor_unfiltered['LIBRARY_NAME']

# Create tuple pairs for matching
anchor_pairs = synergies_anchor[['drug1', 'drug2']].apply(tuple, axis=1)
anchor_unf_pairs = all_anchor_unfiltered[['drug1', 'drug2']].apply(tuple, axis=1)

detected_set = set(detected_pairs.apply(tuple, axis=1))
detectable_set = set(detectable_pairs.apply(tuple, axis=1))

# Rows corresponding to detected pairs (from filtered dataset)
anchor_detected = synergies_anchor[anchor_pairs.isin(detected_set)].set_index(['drug1', 'drug2'])

# Rows corresponding to detectable pairs (from unfiltered dataset)
anchor_detectable = all_anchor_unfiltered[anchor_unf_pairs.isin(detectable_set)].set_index(['drug1', 'drug2'])

# %%
anchor_detected
# Out:
#                            COMBI_ID    Tissue CELL_LINE_NAME  COSMIC_ID  \
# drug1       drug2
# Axitinib    Sorafenib     1021:1085    Breast       CAL-85-1     910852
# Sorafenib   Dasatinib     1085:1079  Pancreas          DAN-G    1290797
# Ruxolitinib Dasatinib     1507:1079  Pancreas           KP-4     753572
# Sorafenib   Galunisertib  1085:2265  Pancreas           PSN1     910546
#
#                          ANCHOR_ID  ANCHOR_NAME           ANCHOR_TARGET  \
# drug1       drug2
# Axitinib    Sorafenib         1021     Axitinib       PDGFR, KIT, VEGFR
# Sorafenib   Dasatinib         1085    Sorafenib  PDGFR, KIT, VEGFR, RAF
# Ruxolitinib Dasatinib         1507  Ruxolitinib              JAK1, JAK2
# Sorafenib   Galunisertib      1085    Sorafenib  PDGFR, KIT, VEGFR, RAF
#
#                           ANCHOR_PATHWAY ANCHOR_DRUG_TYPE  \
# drug1       drug2
# Axitinib    Sorafenib      RTK signaling         Targeted
# Sorafenib   Dasatinib     Other, kinases         Targeted
# ...

# %%
detected_pairs.shape[0] / 2
# Out:
# 4.0

# %%
detectable_pairs.shape[0] / 2
# Out:
# 6.0

# %%
anchor_detected
# Out:
#                            COMBI_ID    Tissue CELL_LINE_NAME  COSMIC_ID  \
# drug1       drug2
# Axitinib    Sorafenib     1021:1085    Breast       CAL-85-1     910852
# Sorafenib   Dasatinib     1085:1079  Pancreas          DAN-G    1290797
# Ruxolitinib Dasatinib     1507:1079  Pancreas           KP-4     753572
# Sorafenib   Galunisertib  1085:2265  Pancreas           PSN1     910546
#
#                          ANCHOR_ID  ANCHOR_NAME           ANCHOR_TARGET  \
# drug1       drug2
# Axitinib    Sorafenib         1021     Axitinib       PDGFR, KIT, VEGFR
# Sorafenib   Dasatinib         1085    Sorafenib  PDGFR, KIT, VEGFR, RAF
# Ruxolitinib Dasatinib         1507  Ruxolitinib              JAK1, JAK2
# Sorafenib   Galunisertib      1085    Sorafenib  PDGFR, KIT, VEGFR, RAF
#
#                           ANCHOR_PATHWAY ANCHOR_DRUG_TYPE  \
# drug1       drug2
# Axitinib    Sorafenib      RTK signaling         Targeted
# Sorafenib   Dasatinib     Other, kinases         Targeted
# ...

# %%
drug_to_targets['Sorafenib']+drugbank_to_targets['Sorafenib']
# Out:
# ['PDGFRA', 'KIT', 'VEGFA', 'RAF1', 'EGFR', 'FLT4', 'KDR', 'FLT1', 'PDGFRB']

# %%
drug_to_targets['Dasatinib']+drugbank_to_targets['Dasatinib']
# Out:
# ['ABL1', 'SRC', 'EPHA1', 'PDGFRA', 'KIT', 'LCK', 'PDGFRB']

# %%
drug_to_targets['Axitinib']+drugbank_to_targets['Axitinib']
# Out:
# ['PDGFRA', 'KIT', 'FLT1', 'KDR', 'FLT4', 'FLT1', 'KDR', 'FLT4']

# %%
all_detected_df.query('drug1 == "Axitinib" and drug2 == "Sorafenib"')
# Out:
#                         interaction     drug1      drug2     targets1  \
# 0  FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  Axitinib  Sorafenib  {FLT1, KDR}
# 5         PDGFB+PDGFRB&PDGFB+PDGFRA  Axitinib  Sorafenib     {PDGFRB}
#
#            targets2
# 0  {PDGFRB, PDGFRA}
# 5          {PDGFRA}

# %%
all_detected_df.query('drug1 == "Sorafenib" and drug2 == "Dasatinib"')
# Out:
#                         interaction      drug1      drug2     targets1  \
# 1  FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  Sorafenib  Dasatinib  {FLT1, KDR}
# 6         PDGFB+PDGFRB&PDGFB+PDGFRA  Sorafenib  Dasatinib     {PDGFRB}
#
#            targets2
# 1  {PDGFRB, PDGFRA}
# 6          {PDGFRA}

# %%
all_detected_df.query('drug1 == "Ruxolitinib" and drug2 == "Dasatinib"')
# Out:
#                              interaction        drug1      drug2 targets1  \
# 2        ITGA4_ITGB1+PLAUR&CD8A_CD8B+LCK  Ruxolitinib  Dasatinib  {PLAUR}
# 3  ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB  Ruxolitinib  Dasatinib  {PLAUR}
#
#            targets2
# 2             {LCK}
# 3  {PDGFRB, PDGFRA}

# %%
all_detected_df.query('drug1 == "Sorafenib" and drug2 == "Galunisertib"')
# Out:
#                              interaction      drug1         drug2  \
# 4  PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1  Sorafenib  Galunisertib
#
#            targets1 targets2
# 4  {PDGFRB, PDGFRA}  {TGFB1}

# %%
all_cell_lines = all_anchor_unfiltered

detectable_cell_lines = []

for i, row in detectable_pairs.iterrows():
    drug1 = row['drug1']
    drug2 = row['drug2']
    
    tmp = all_cell_lines.query('drug1 == @drug1 and drug2 == @drug2')
    detectable_cell_lines.append(tmp)
    
detectable_cell_lines = pd.concat(detectable_cell_lines)

# Max concentration is 10, pair is considered synergystic only if IC50 is less
# than half of max tested concentration (otherwise is fitted outside distribution)
# max concentration is 10
detectable_cell_lines = detectable_cell_lines.query('SYNERGY_XMID < 10')

detectable_cell_lines = detectable_cell_lines.sort_values(by='SYNERGY_DELTA_AUC')

# %%
all_matrix_unfiltered.synergy.sum()
# Out:
# synergy
# False    73981
# True     10074
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df = detectable_cell_lines[
    ['SYNERGY_DELTA_XMID', 'SYNERGY_DELTA_EMAX', 'Synergy']
].copy()

df['Synergy_num'] = df['Synergy'].astype(int)

plt.figure()

sc = plt.scatter(
    df['SYNERGY_DELTA_XMID'],
    df['SYNERGY_DELTA_EMAX'],
    c=df['Synergy_num'],
    cmap='coolwarm',
    alpha=0.7
)

plt.xlabel('SYNERGY_DELTA_XMID')
plt.ylabel('SYNERGY_DELTA_EMAX')
plt.title('Synergy: Delta XMID vs Delta EMAX')

plt.colorbar(sc, label='Synergy (0=False, 1=True)')
plt.show()

# %%
df
# Out:
#         SYNERGY_DELTA_XMID  SYNERGY_DELTA_EMAX  Synergy  Synergy_num
# 277149           -2.353803           -0.137120    False            0
# 274150           -1.571114           -0.165300    False            0
# 274144           -1.354060           -0.140052    False            0
# 277155           -1.539292           -0.086570    False            0
# 285620           -1.285072           -0.114149    False            0
# ...                    ...                 ...      ...          ...
# 285659            2.486420            0.189328    False            0
# 285560            2.047590            0.181561    False            0
# 275376            4.809413            0.206875     True            1
# 84666             3.065226            0.203522     True            1
# 285543            3.071893            0.244697     True            1
#
# [266 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

def plot_top_synergy(df, N=15, figsize=(7.08, 7.08), fontsize=8,
                     color_non=graycolor,   # color1 — non-synergistic
                     color_syn=tcolor,      # color2 — synergistic
                     dedup_cols=('drug1', 'drug2', 'CELL_LINE_NAME')):
    """Top-N by Borda rank-aggregate of ΔEmax and ΔXMID, shown as
    expected→observed dumbbells, colored by synergy status.
    Duplicate measurements of the same pair+cell line are collapsed to a
    single best representative (synergistic first, then highest Borda)
    BEFORE the top-N cut, so N distinct combinations survive.

    figsize : (w, h) tuple; defaults to (15, height scaled to N).
    fontsize : single value applied to every text element in the figure.
    """
    # Borda: rank each delta (ascending → larger delta = higher rank), sum.
    borda = (df['SYNERGY_DELTA_EMAX'].rank(ascending=True)
             + df['SYNERGY_DELTA_XMID'].rank(ascending=True))   # NaN in either → NaN
    # ---- collapse duplicates: best row per (drug1, drug2, cell line) ----
    work = df.copy()
    work['borda'] = borda
    work['_syn']  = work['Synergy'].astype(bool)
    work = (work.sort_values(['_syn', 'borda'], ascending=[False, False])
                .drop_duplicates(subset=list(dedup_cols), keep='first'))
    # ---- top-N on the deduplicated frame ----
    sel = work.nlargest(N, 'borda').copy()
    sel = sel.sort_values('borda')                              # best at top
    sel['label'] = sel.apply(
        lambda r: f"{r['drug1']} + {r['drug2']} ({r['CELL_LINE_NAME']})", axis=1)

    cmap = {True: color_syn, False: color_non}
    y = list(range(len(sel)))
    cols = [cmap[bool(s)] for s in sel['Synergy']]

    panels = [('Efficacy ($ΔE_{max}$)', 'SYNERGY_OBS_EMAX', 'SYNERGY_EXP_EMAX'),  # obs, exp
              ('Potency ($ΔIC_{50}$)',  'SYNERGY_XMID',      'LIBRARY_XMID')]      # obs, exp
    xlabels = ['$E_{max}$', '$IC_{50}$']

    fig, axes = plt.subplots(1, 2, figsize=figsize, sharey=True)

    for ax, (title, obs_c, exp_c), xlab in zip(axes, panels, xlabels):
        for yi, (_, r) in zip(y, sel.iterrows()):
            ax.plot([r[exp_c], r[obs_c]], [yi, yi], color=cmap[bool(r['Synergy'])],
                    lw=2, alpha=.7, zorder=1)
        ax.scatter(sel[obs_c], y, facecolors=cols,    edgecolors=cols, s=10, zorder=3)  # observed
        ax.scatter(sel[exp_c], y, facecolors='white', edgecolors=cols, s=10, zorder=2)  # expected
        ax.set_title(title, fontsize=fontsize)
        ax.set_xlabel(xlab, fontsize=fontsize)
        ax.grid(axis='x', ls=':', alpha=.4)
        ax.tick_params(axis='both', labelsize=fontsize)
        
        ax.set_ylim(-N/4, N) # allow some space at the bottom for the legend
        ax.spines[['right', 'top']].set_visible(False)

    axes[0].set_yticks(y)
    axes[0].set_yticklabels(sel['label'], fontsize=fontsize)

    # grouped legend: heading per synergy status, obs/exp markers beneath in that color
    def _h(color, label, hollow=False, head=False):
        if head:                                   # heading row: no marker, just text
            return mlines.Line2D([], [], ls='', marker='', label=label)
        return mlines.Line2D([], [], color=color, ls='', marker='o',
                             mfc='white' if hollow else color, label=label)

    legend_handles = [
        _h(None,      'Synergistic',          head=True),
        _h(color_syn, '  observed'),
        _h(color_syn, '  expected', hollow=True),
        _h(None,      'Non-synergistic',      head=True),
        _h(color_non, '  observed'),
        _h(color_non, '  expected', hollow=True),
    ]
    for ax in axes:
        ax.legend(handles=legend_handles, loc='lower right',
                  fontsize=fontsize, frameon=False,
                  handletextpad=0.5, labelspacing=0.35, ncol=2)

    fig.suptitle('Synergistic Drug Pairs', y=0.95, fontsize=fontsize)
    fig.tight_layout()
    plt.show()
    return sel

sel = plot_top_synergy(detectable_cell_lines, N=25, figsize=(7.08, 4), fontsize=7)

# %%
detectable_cell_lines.Synergy.sum() / detectable_cell_lines.shape[0]
# Out:
# np.float64(0.022556390977443608)

# %%
all_cell_lines.Synergy.sum() / all_cell_lines.shape[0]
# Out:
# np.float64(0.031687826711199935)

# %%
all_cell_lines

# %%
detectable_cell_lines.eval('LIBRARY_XMID - SYNERGY_XMID')
# Out:
# 277149   -2.353803
# 274150   -1.571114
# 274144   -1.354060
# 277155   -1.539292
# 285620   -1.285072
#             ...
# 285659    2.486420
# 285560    2.047590
# 275376    4.809413
# 84666     3.065226
# 285543    3.071893
# Length: 266, dtype: float64

# %%
detectable_cell_lines['SYNERGY_DELTA_XMID']
# Out:
# 277149   -2.353803
# 274150   -1.571114
# 274144   -1.354060
# 277155   -1.539292
# 285620   -1.285072
#             ...
# 285659    2.486420
# 285560    2.047590
# 275376    4.809413
# 84666     3.065226
# 285543    3.071893
# Name: SYNERGY_DELTA_XMID, Length: 266, dtype: float64

# %%
detectable_cell_lines.eval('SYNERGY_OBS_EMAX - SYNERGY_EXP_EMAX')
# Out:
# 277149    0.137120
# 274150    0.165300
# 274144    0.140052
# 277155    0.086570
# 285620    0.114149
#             ...
# 285659   -0.189328
# 285560   -0.181561
# 275376   -0.206875
# 84666    -0.203522
# 285543   -0.244697
# Length: 266, dtype: float64

# %%
detectable_cell_lines['SYNERGY_DELTA_EMAX']
# Out:
# 277149   -0.137120
# 274150   -0.165300
# 274144   -0.140052
# 277155   -0.086570
# 285620   -0.114149
#             ...
# 285659    0.189328
# 285560    0.181561
# 275376    0.206875
# 84666     0.203522
# 285543    0.244697
# Name: SYNERGY_DELTA_EMAX, Length: 266, dtype: float64

# %%
detectable_cell_lines

# %%
detectable_cell_lines.columns
# Out:
# Index(['BARCODE', 'COMBI_ID', 'Tissue', 'CELL_LINE_NAME', 'SIDM', 'COSMIC_ID',
#        'ANCHOR_ID', 'ANCHOR_NAME', 'ANCHOR_TARGET', 'ANCHOR_PATHWAY',
#        'ANCHOR_DRUG_TYPE', 'ANCHOR_Clin_Rel', 'ANCHOR_CONC', 'LIBRARY_ID',
#        'LIBRARY_NAME', 'LIBRARY_TARGET', 'LIBRARY_PATHWAY',
#        'LIBRARY_DRUG_TYPE', 'LIBRARY_Clin_Rel', 'LIBRARY_CONC',
#        'ANCHOR_VIABILITY', 'LIBRARY_RMSE', 'LIBRARY_EMAX', 'LIBRARY_XMID',
#        'LIBRARY_XMID_uM', 'LIBRARY_AUC', 'LIBRARY_fAUC', 'SYNERGY_RMSE',
#        'SYNERGY_EXP_EMAX', 'SYNERGY_OBS_EMAX', 'SYNERGY_DELTA_EMAX',
#        'SYNERGY_XMID', 'SYNERGY_XMID_uM', 'SYNERGY_DELTA_XMID',
#        'SYNERGY_DELTA_XMID_uM', 'SYNERGY_EXP_AUC', 'SYNERGY_OBS_AUC',
#        'SYNERGY_EXP_fAUC', 'SYNERGY_OBS_fAUC', 'SYNERGY_DELTA_AUC',
#        'SYNERGY_DELTA_fAUC', 'Synergy', 'DAY1_NORM_MEAN', 'DAY1_NORM_SD',
#        'GROWTH_RATE', 'DOUBLING_TIME', 'drug1', 'drug2'],
#       dtype='object')

# %%
detectable_cell_lines.query('drug1 == "Ruxolitinib" and drug2 == "Dasatinib" and CELL_LINE_NAME == "PA-TU-8988T"')#.iloc[:, 10:20]
# Out:
#         BARCODE   COMBI_ID    Tissue CELL_LINE_NAME       SIDM  COSMIC_ID  \
# 285610    38521  1507:1079  Pancreas    PA-TU-8988T  SIDM00453    1240201
# 285593    38521  1507:1079  Pancreas    PA-TU-8988T  SIDM00453    1240201
# 285676    38799  1507:1079  Pancreas    PA-TU-8988T  SIDM00453    1240201
# 285510    38104  1507:1079  Pancreas    PA-TU-8988T  SIDM00453    1240201
# 285493    38104  1507:1079  Pancreas    PA-TU-8988T  SIDM00453    1240201
# 285659    38799  1507:1079  Pancreas    PA-TU-8988T  SIDM00453    1240201
# 285560    38315  1507:1079  Pancreas    PA-TU-8988T  SIDM00453    1240201
# 285543    38315  1507:1079  Pancreas    PA-TU-8988T  SIDM00453    1240201
#
#        ANCHOR_ID  ANCHOR_NAME ANCHOR_TARGET  ANCHOR_PATHWAY  ...  \
# 285610      1507  Ruxolitinib    JAK1, JAK2  Other, kinases  ...
# 285593      1507  Ruxolitinib    JAK1, JAK2  Other, kinases  ...
# 285676      1507  Ruxolitinib    JAK1, JAK2  Other, kinases  ...
# ...

# %%
detectable_cell_lines.query('drug1 == "Dasatinib" and drug2 == "Ruxolitinib"')#.iloc[:, 10:20]
# Out:
#         BARCODE   COMBI_ID    Tissue CELL_LINE_NAME       SIDM  COSMIC_ID  \
# 274874    38579  1079:1507  Pancreas           PSN1  SIDM00469     910546
#
#        ANCHOR_ID ANCHOR_NAME                  ANCHOR_TARGET  ANCHOR_PATHWAY  \
# 274874      1079   Dasatinib  ABL, SRC, Ephrins, PDGFR, KIT  Other, kinases
#
#         ... SYNERGY_OBS_fAUC SYNERGY_DELTA_AUC SYNERGY_DELTA_fAUC Synergy  \
# 274874  ...           0.6628          0.047379           0.063323    True
#
#        DAY1_NORM_MEAN DAY1_NORM_SD GROWTH_RATE DOUBLING_TIME      drug1  \
# 274874       0.285165     0.037003    1.163445     41.926935  Dasatinib
#
#               drug2
# 274874  Ruxolitinib
#
# [1 rows x 48 columns]

# %%
all_detected_df
# Out:
#                              interaction        drug1         drug2  \
# 0       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB     Axitinib     Sorafenib
# 1       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib     Dasatinib
# 2        ITGA4_ITGB1+PLAUR&CD8A_CD8B+LCK  Ruxolitinib     Dasatinib
# 3  ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB  Ruxolitinib     Dasatinib
# 4  PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1    Sorafenib  Galunisertib
# 5              PDGFB+PDGFRB&PDGFB+PDGFRA     Axitinib     Sorafenib
# 6              PDGFB+PDGFRB&PDGFB+PDGFRA    Sorafenib     Dasatinib
#
#            targets1          targets2
# 0       {FLT1, KDR}  {PDGFRB, PDGFRA}
# 1       {FLT1, KDR}  {PDGFRB, PDGFRA}
# 2           {PLAUR}             {LCK}
# 3           {PLAUR}  {PDGFRB, PDGFRA}
# 4  {PDGFRB, PDGFRA}           {TGFB1}
# 5          {PDGFRB}          {PDGFRA}
# 6          {PDGFRB}          {PDGFRA}

# %%
detectable_cell_lines.query('Synergy')
# Out:
#         BARCODE   COMBI_ID    Tissue CELL_LINE_NAME       SIDM  COSMIC_ID  \
# 274874    38579  1079:1507  Pancreas           PSN1  SIDM00469     910546
# 256306    38297  1507:1079  Pancreas           KP-4  SIDM00301     753572
# 246484    35918  1085:1079  Pancreas          DAN-G  SIDM00950    1290797
# 275376    39390  1085:2265  Pancreas           PSN1  SIDM00469     910546
# 84666     28083  1021:1085    Breast       CAL-85-1  SIDM00928     910852
# 285543    38315  1507:1079  Pancreas    PA-TU-8988T  SIDM00453    1240201
#
#        ANCHOR_ID  ANCHOR_NAME                  ANCHOR_TARGET  ANCHOR_PATHWAY  \
# 274874      1079    Dasatinib  ABL, SRC, Ephrins, PDGFR, KIT  Other, kinases
# 256306      1507  Ruxolitinib                     JAK1, JAK2  Other, kinases
# 246484      1085    Sorafenib         PDGFR, KIT, VEGFR, RAF  Other, kinases
# 275376      1085    Sorafenib         PDGFR, KIT, VEGFR, RAF  Other, kinases
# ...

# %%
detectable_cell_lines.query('drug1 == "Ruxolitinib" and drug2 == "Dasatinib"')[[ 'COMBI_ID', 'Tissue', 'CELL_LINE_NAME', 'SIDM', 'COSMIC_ID',
       'ANCHOR_ID', 'ANCHOR_NAME', 'ANCHOR_TARGET', 'ANCHOR_PATHWAY',
       'ANCHOR_DRUG_TYPE', 'ANCHOR_Clin_Rel', 'ANCHOR_CONC', 'LIBRARY_ID',
       'LIBRARY_NAME', 'LIBRARY_TARGET', 'LIBRARY_PATHWAY']]#.drop_duplicates()
# Out:
#          COMBI_ID    Tissue CELL_LINE_NAME       SIDM  COSMIC_ID ANCHOR_ID  \
# 267248  1507:1079  Pancreas     PANC-03-27  SIDM01138     925346      1507
# 263516  1507:1079  Pancreas     PANC-04-03  SIDM01137    1298476      1507
# 263499  1507:1079  Pancreas     PANC-04-03  SIDM01137    1298476      1507
# 265163  1507:1079  Pancreas     PANC-10-05  SIDM01135     925348      1507
# 285610  1507:1079  Pancreas    PA-TU-8988T  SIDM00453    1240201      1507
# 238728  1507:1079  Pancreas           YAPC  SIDM00411     909904      1507
# 250537  1507:1079  Pancreas          KP-1N  SIDM00583    1298216      1507
# 263463  1507:1079  Pancreas     PANC-04-03  SIDM01137    1298476      1507
# 242339  1507:1079  Pancreas         MZ1-PC  SIDM00053     753595      1507
# 289442  1507:1079  Pancreas         SU8686  SIDM01188    1240218      1507
# 248487  1507:1079  Pancreas        Hs-766T  SIDM00664    1298141      1507
# ...

# %%
# SYNERGY_EXP_EMAX - SYNERGY_OBS_EMAX = SYNERGY_DELTA_EMAX
# LIBRARY_XMID - SYNERGY_XMID = SYNERGY_DELTA_XMID

# %%
import numpy as np

# thresholds from paper
EMAX_THRESH = -0.2
XMID_THRESH = -np.log10(8)   # ≈ -0.903

df = detectable_cell_lines.copy()

# conditions
emax_ok = df['SYNERGY_DELTA_EMAX'] <= EMAX_THRESH
xmid_ok = df['SYNERGY_DELTA_XMID'] <= XMID_THRESH

# expected synergy based on rules
expected_synergy = emax_ok | xmid_ok

# compare with provided label
df['expected_synergy'] = expected_syneraagy

# mismatches
mismatch = df[df['Synergy'] != df['expected_synergy']]

print("Total rows:", len(df))
print("Synergy True:", df['Synergy'].sum())
print("Expected True:", expected_synergy.sum())
print("Mismatches:", len(mismatch))

# inspect a few mismatches
print(mismatch[['SYNERGY_DELTA_EMAX', 'SYNERGY_DELTA_XMID', 'Synergy']].head())
# Out:
# Mismatches: 107

# %%
EMAX_THRESH = 0.2
XMID_THRESH = 2.0

emax_ok = df['SYNERGY_DELTA_EMAX'] >= EMAX_THRESH
xmid_ok = df['SYNERGY_DELTA_XMID'] >= XMID_THRESH

expected_synergy = emax_ok | xmid_ok

mismatch = df[df['Synergy'] != expected_synergy]

print("Mismatches:", len(mismatch))

# %%
df[df['Synergy']][[
    'SYNERGY_DELTA_EMAX',
    'SYNERGY_DELTA_XMID',
    'SYNERGY_DELTA_AUC'
]]
# Out:
#         SYNERGY_DELTA_EMAX  SYNERGY_DELTA_XMID  SYNERGY_DELTA_AUC
# 274874            0.230715            3.352523           0.047379
# 256306            0.223359            1.849230           0.089480
# 246484            0.240397            3.712798           0.105437
# 275376            0.206875            4.809413           0.133143
# 84666             0.203522            3.065226           0.134734
# 285543            0.244697            3.071893           0.166464

# %%
df[~df['Synergy']]['SYNERGY_DELTA_EMAX'].describe()
df[~df['Synergy']]['SYNERGY_DELTA_XMID'].describe()
# Out:
# count    1003.000000
# mean        0.098597
# std         1.604609
# min        -7.332558
# 25%        -0.814649
# 50%         0.028754
# 75%         0.957778
# max         7.366873
# Name: SYNERGY_DELTA_XMID, dtype: float64

# %%
cell_lines.query('ANCHOR_NAME == "Axitinib" and LIBRARY_NAME == "Sorafenib"').sort_values(by='SYNERGY_DELTA_AUC')
# Out:
#         BARCODE   COMBI_ID  Tissue  CELL_LINE_NAME       SIDM  COSMIC_ID  \
# 86990     25850  1021:1085  Breast         HCC1419  SIDM00882     907045
# 145178    30688  1021:1085  Breast         MFM-223  SIDM00332     910948
# 142179    25856  1021:1085  Breast        Hs-578-T  SIDM00135     905957
# 139337    25819  1021:1085  Breast          BT-549  SIDM00122     905951
# 149234    30697  1021:1085  Breast      MDA-MB-330  SIDM00631    1330941
# ...         ...        ...     ...             ...        ...        ...
# 143540    23600  1021:1085  Breast      MDA-MB-361  SIDM00528     908121
# 92071     23608  1021:1085  Breast      MDA-MB-157  SIDM00529     925338
# 102773    25030  1021:1085  Breast          EVSA-T  SIDM01042     906862
# 151764    28750  1021:1085  Breast  MDA-MB-175-VII  SIDM00633     908120
# 84666     28083  1021:1085  Breast        CAL-85-1  SIDM00928     910852
#
#        ANCHOR_ID ANCHOR_NAME      ANCHOR_TARGET ANCHOR_PATHWAY  ...  \
# ...

# %%
#drug_pairs_df['gdsc_combinations_synergy'] = False
#all_detected_df['gdsc_combinations_synergy'] = True
#all_detected_df['type1'] = 'Small Molecule'
#all_detected_df['type2'] = 'Small Molecule'

#drugdf = pd.concat([all_detected_df.rename(columns={'interaction': 'clique'}), drug_pairs_df])

#drugdf = drugdf.drop_duplicates(subset=['clique', 'drug1','drug2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 drug_pairs_df['gdsc_combinations_synergy'] = False
#       2 all_detected_df['gdsc_combinations_synergy'] = True
#       3 all_detected_df['type1'] = 'Small Molecule'
#
# NameError: name 'drug_pairs_df' is not defined

# %%
#drugdf.to_csv('/home/lnemati/pathway_crosstalk/results/crosstalk/drug_pairs_with_synergies.csv', index=False)

# %%
## Initialize synergy columns
#drug_pairs_df['gdsc_combinations_synergy'] = False
#
## Expand with GDSC targets
#drug_pairs_df['targets1'] = drug_pairs_df['drug1'].apply(lambda x: sorted(merge_targets(x, drug_to_targets, drugbank_to_targets)))
#drug_pairs_df['targets2'] = drug_pairs_df['drug2'].apply(lambda x: sorted(merge_targets(x, drug_to_targets, drugbank_to_targets)))
#

# %%
for _, row in all_detected_df.iterrows():
    interaction = row['interaction']
    drug1 = row['drug1']
    drug2 = row['drug2']

    # Check both possible orderings
    mask = (
        ((drug_pairs_df.drug1 == drug1) & (drug_pairs_df.drug2 == drug2)) |
        ((drug_pairs_df.drug1 == drug2) & (drug_pairs_df.drug2 == drug1))
    )
    mask &= (drug_pairs_df.clique == interaction)

    matches = drug_pairs_df[mask]
    if not matches.empty:
        pass
    else:
        print(f"No match for {interaction}, {drug1}, {drug2}")
# Out:
# No match for PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1, Sorafenib, Galunisertib
# No match for PDGFB+PDGFRB&PDGFB+PDGFRA, Axitinib, Sorafenib
# No match for PDGFB+PDGFRB&PDGFB+PDGFRA, Sorafenib, Dasatinib

# %%
drug_pairs_df.query('clique == "PDGFB+PDGFRB&PDGFB+PDGFRA"')
# Out:
#                         clique        drug1       targets1           type1  \
# 137  PDGFB+PDGFRB&PDGFB+PDGFRA  Becaplermin       [PDGFRB]  Small Molecule
# 138  PDGFB+PDGFRB&PDGFB+PDGFRA  Becaplermin       [PDGFRB]  Small Molecule
# 139  PDGFB+PDGFRB&PDGFB+PDGFRA  Becaplermin       [PDGFRB]  Small Molecule
# 140  PDGFB+PDGFRB&PDGFB+PDGFRA  Becaplermin       [PDGFRB]  Small Molecule
# 141  PDGFB+PDGFRB&PDGFB+PDGFRA  Becaplermin       [PDGFRB]  Small Molecule
# ..                         ...          ...            ...             ...
# 362  PDGFB+PDGFRB&PDGFB+PDGFRA  Pralsetinib  [KDR, PDGFRB]  Small Molecule
# 363  PDGFB+PDGFRB&PDGFB+PDGFRA  Pralsetinib  [KDR, PDGFRB]  Small Molecule
# 364  PDGFB+PDGFRB&PDGFB+PDGFRA  Pralsetinib  [KDR, PDGFRB]  Small Molecule
# 365  PDGFB+PDGFRB&PDGFB+PDGFRA  Pralsetinib  [KDR, PDGFRB]  Small Molecule
# 366  PDGFB+PDGFRB&PDGFB+PDGFRA  Pralsetinib  [KDR, PDGFRB]  Small Molecule
#
# ...

# %%
# Out:
# 0        [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
# 1                                    [CCR5, CD4]
# 2        [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
# 3                                    [CCR5, CD4]
# 4        [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
#                           ...
# 23638    [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
# 23639    [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
# 23640    [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
# 23641                                     [CCR4]
# 23642                                     [CCR4]
# Name: drug1, Length: 20450, dtype: object

# %%
drug_pairs_df['targets1'].apply(sorted)
# Out:
# 0        [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
# 1                                    [CCR5, CD4]
# 2        [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
# 3                                    [CCR5, CD4]
# 4        [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
#                           ...
# 23638    [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
# 23639    [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
# 23640    [CD4, CD86, ITGAL, ITGAV, ITGB1, ITGB3]
# 23641                                     [CCR4]
# 23642                                     [CCR4]
# Name: targets1, Length: 20450, dtype: object

# %%
drug_to_targets['Sorafenib']
# Out:
# ['PDGFRA', 'KIT', 'VEGFA', 'RAF1']

# %%
drugs_df.set_index('drug').loc['Ruxolitinib']

# %%
anchor_detectable['Tissue'].value_counts()
# Out:
# Tissue
# Pancreas    913
# Breast       96
# Name: count, dtype: int64

# %%
all_detectable_unfiltered_df.interaction.value_counts()
# Out:
# interaction
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB         2
# ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB    2
# PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1    2
# PDGFB+PDGFRB&PDGFB+PDGFRA                2
# ITGA4_ITGB1+PLAUR&CD8A_CD8B+LCK          1
# Name: count, dtype: int64

# %%
all_detected_df.interaction.value_counts()
# Out:
# interaction
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB         2
# PDGFB+PDGFRB&PDGFB+PDGFRA                2
# ITGA4_ITGB1+PLAUR&CD8A_CD8B+LCK          1
# ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB    1
# PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1    1
# Name: count, dtype: int64

# %%
set(all_detectable_unfiltered_df.drug1) | set(all_detectable_unfiltered_df.drug2)
# Out:
# {'Axitinib', 'Dasatinib', 'Galunisertib', 'Ruxolitinib', 'Sorafenib'}

# %%
set(all_detected_df.drug1) | set(all_detected_df.drug2)
# Out:
# {'Axitinib', 'Dasatinib', 'Galunisertib', 'Ruxolitinib', 'Sorafenib'}

# %%
import pandas as pd

def make_row_key(df):
    """Create a hashable key for each row ignoring drug order and using frozensets for targets."""
    return df.apply(lambda x: (
        frozenset([x['drug1'], x['drug2']]),  # unordered drug pair
        x['Interaction'],
        frozenset(x['targets1']),
        frozenset(x['targets2'])
    ), axis=1)

# Create sets of row keys
subset_keys = set(make_row_key(all_detected_df))
unfiltered_keys = set(make_row_key(all_detectable_unfiltered_df))

# Check if subset
is_subset = subset_keys.issubset(unfiltered_keys)
print("Is all_detected_df a subset of all_detectable_unfiltered_df?", is_subset)

# Optionally, see which rows are missing
missing_rows = subset_keys - unfiltered_keys
print("Rows in filtered but not in unfiltered:", missing_rows)

# Optionally, see which rows are not synergies
missing_rows = unfiltered_keys - subset_keys
print("Rows in unfiltered but not in ufiltered:", missing_rows)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/WGCNA/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Interaction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[317], line 13
#       5     return df.apply(lambda x: (
# ...

# %%
all_anchor_unfiltered
# Out:
#         BARCODE   COMBI_ID    Tissue CELL_LINE_NAME       SIDM  COSMIC_ID  \
# 0         14576  1022:1005    Breast        CAL-120  SIDM00940     906826
# 1         14576  1191:1005    Breast        CAL-120  SIDM00940     906826
# 2         14576  1558:1005    Breast        CAL-120  SIDM00940     906826
# 3         14576  1047:1005    Breast        CAL-120  SIDM00940     906826
# 4         14576  1561:1005    Breast        CAL-120  SIDM00940     906826
# ...         ...        ...       ...            ...        ...        ...
# 296702    38250  1080:2265  Pancreas           HPAC  SIDM00670    1298136
# 296703    38250  1558:2265  Pancreas           HPAC  SIDM00670    1298136
# 296704    38250  1558:2265  Pancreas           HPAC  SIDM00670    1298136
# 296705    38250  1079:2265  Pancreas           HPAC  SIDM00670    1298136
# 296706    38250  1053:2265  Pancreas           HPAC  SIDM00670    1298136
#
#        ANCHOR_ID    ANCHOR_NAME                  ANCHOR_TARGET  \
# ...

# %%
set(all_synergies_filtered['drug1']).difference(all_synergies_unfiltered['drug1'])
# Out:
# {'Sorafenib'}

# %%
set(all_synergies_filtered['drug2']).difference(all_synergies_unfiltered['drug2'])
# Out:
# {'Dasatinib'}

# %%
all_synergies_unfiltered.query('drug1 == "Ruxolitinib" and drug2 == "Dasatinib"')
# Out:
#       BARCODE   COMBI_ID    Tissue CELL_LINE_NAME       SIDM  COSMIC_ID  \
# 2319  38077.0  1507:1079  Pancreas         SUIT-2  SIDM00371  1240219.0
# 2325  38077.0  1507:1079  Pancreas         SUIT-2  SIDM00371  1240219.0
# 2330  38072.0  1507:1079  Pancreas         SUIT-2  SIDM00371  1240219.0
# 2334  38072.0  1507:1079  Pancreas         SUIT-2  SIDM00371  1240219.0
# 2340  38324.0  1507:1079  Pancreas         SUIT-2  SIDM00371  1240219.0
# ...       ...        ...       ...            ...        ...        ...
# 4877  38288.0  1507:1079  Pancreas          KP-1N  SIDM00583  1298216.0
# 4883  38494.0  1507:1079  Pancreas          KP-1N  SIDM00583  1298216.0
# 4887  38494.0  1507:1079  Pancreas          KP-1N  SIDM00583  1298216.0
# 4943  38555.0  1507:1079  Pancreas           HPAC  SIDM00670  1298136.0
# 4947  38555.0  1507:1079  Pancreas           HPAC  SIDM00670  1298136.0
#
#      ANCHOR_ID        drug1 ANCHOR_TARGET  ANCHOR_PATHWAY  ...  \
# ...

# %%
all_synergies_unfiltered.query('drug2 == "Ruxolitinib" and drug1 == "Dasatinib"')['LIBRARY_TARGET'].value_counts()
# Out:
# LIBRARY_TARGET
# JAK1, JAK2    88
# Name: count, dtype: int64

# %%
all_anchor_unf_prepared.query('drug1 == "Ruxolitinib" and drug2 == "Dasatinib"')['LIBRARY_TARGET'].value_counts()
# Out:
# LIBRARY_TARGET
# ABL, SRC, Ephrins, PDGFR, KIT    90
# Name: count, dtype: int64

# %%
all_anchor_unf_prepared.query('drug2 == "Ruxolitinib" and drug1 == "Dasatinib"')['LIBRARY_TARGET'].value_counts()
# Out:
# LIBRARY_TARGET
# JAK1, JAK2    88
# Name: count, dtype: int64

# %%
synergies_anchor_prepared.query('drug1 == "Ruxolitinib" and drug2 == "Dasatinib"')['LIBRARY_TARGET'].value_counts()
# Out:
# LIBRARY_TARGET
# ABL, SRC, Ephrins, PDGFR, KIT    1
# Name: count, dtype: int64

# %%
synergies_anchor_prepared.query('drug2 == "Ruxolitinib" and drug1 == "Dasatinib"')['LIBRARY_TARGET'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
clique_drugs = pd.read_csv('/home/lnemati/pathway_crosstalk/results/crosstalk/all_ccc_complex_pairs/adj/motifs/tumor/approved_drug_pairs.csv', index_col=0)
synergies_anchor = pd.read_csv('/home/lnemati/drug_synergies/only_synergistic_anchor_drugs.csv', index_col=0)
synergies_matrix = pd.read_csv('/home/lnemati/drug_synergies/only_synergistic_matrix_drugs.csv', index_col=0)
gdsc_drugs = pd.read_csv('/home/lnemati/drug_synergies/GDSC_drugs.csv', index_col=0)
gdsc_drugs['HGCN_TARGETS'] = gdsc_drugs['HGCN_TARGETS'].str.split(',')

# Map target genes
drug_to_targets = gdsc_drugs.set_index('DRUG_NAME')['HGCN_TARGETS'].to_dict()
synergies_anchor['targets1'] = synergies_anchor['ANCHOR_NAME'].map(drug_to_targets)
synergies_anchor['targets2'] = synergies_anchor['LIBRARY_NAME'].map(drug_to_targets)
synergies_matrix['targets1'] = synergies_matrix['lib1_name'].map(drug_to_targets)
synergies_matrix['targets2'] = synergies_matrix['lib2_name'].map(drug_to_targets)

# Also add targets from drugbank
drugbank_to_targets = drugs_df.groupby('drug')['gene'].apply(list).to_dict()

# --- Function to merge GDSC + DrugBank targets ---
def merge_targets(drug_name, gdsc_mapping, db_mapping):
    gdsc_targets = gdsc_mapping.get(drug_name, [])
    db_targets = db_mapping.get(drug_name, [])
    return list(set(gdsc_targets + db_targets))  # remove duplicates

# --- Update synergies_anchor ---
synergies_anchor['targets1'] = synergies_anchor['ANCHOR_NAME'].apply(
    lambda x: merge_targets(x, drug_to_targets, drugbank_to_targets)
)
synergies_anchor['targets2'] = synergies_anchor['LIBRARY_NAME'].apply(
    lambda x: merge_targets(x, drug_to_targets, drugbank_to_targets)
)

# --- Update synergies_matrix ---
synergies_matrix['targets1'] = synergies_matrix['lib1_name'].apply(
    lambda x: merge_targets(x, drug_to_targets, drugbank_to_targets)
)
synergies_matrix['targets2'] = synergies_matrix['lib2_name'].apply(
    lambda x: merge_targets(x, drug_to_targets, drugbank_to_targets)
)

# --- Combine anchor and matrix datasets ---
# For anchor dataset, rename using targets1/targets2
df1 = synergies_anchor.rename(
    columns={
        'ANCHOR_NAME': 'drug1',
        'LIBRARY_NAME': 'drug2',
    }
)

# For matrix dataset, use existing drug1_target / drug2_target columns
df2 = synergies_matrix.rename(
    columns={
        'lib1_name': 'drug1',
        'lib2_name': 'drug2',

    }
)

# Concatenate
synergies = pd.concat([
    df1[['drug1', 'targets1', 'drug2', 'targets2']],
    df2[['drug1', 'targets1', 'drug2', 'targets2']]
], ignore_index=True)

# Drop those without target
synergies = synergies.dropna()

# --- Filter targets to only genes appearing in cliques ---
all_clique_genes = set(all_clique_genes)
synergies["targets1"] = synergies["targets1"].apply(lambda x: [g for g in x if g in all_clique_genes])
synergies["targets2"] = synergies["targets2"].apply(lambda x: [g for g in x if g in all_clique_genes])

# --- Discard empty rows ---
synergies = synergies[(synergies["targets1"].str.len() > 0) & (synergies["targets2"].str.len() > 0)]

synergies = synergies[~synergies[['drug1', 'drug2']].duplicated()]

# Create unordered drug pair key
synergies['pair'] = synergies.apply(
    lambda x: tuple(sorted([x['drug1'], x['drug2']])),
    axis=1
)

# Keep only one instance of each pair
synergies = synergies.drop_duplicates(subset='pair')

# Optional: remove helper column
synergies = synergies.drop(columns='pair')

                                    
from itertools import product
import pandas as pd

results = []

for _, syn in synergies.iterrows():

    targets1 = set(syn.targets1)
    targets2 = set(syn.targets2)
    
    for _, clique_row in tumor_cliques.iterrows():
        
        genes1 = set(clique_row.int1)
        genes2 = set(clique_row.int2)

        subset1 = targets1 & genes1
        subset2 = targets2 & genes2
        
        if subset1 == subset2:
            continue
        
        if subset1 and subset2:
            results.append({
                "Interaction": clique_row.Interaction,
                "drug1": syn.drug1,
                "drug2": syn.drug2,
                "targets1": subset1,
                "targets2": subset2,
            })

result_df = pd.DataFrame(results)

# %%
result_df
# Out:
#                              Interaction        drug1         drug2  \
# 0       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB     Axitinib     Sorafenib
# 1              PDGFB+PDGFRB&PDGFB+PDGFRA    Sorafenib     Dasatinib
# 2       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib     Dasatinib
# 3  ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB  Ruxolitinib     Dasatinib
# 4        ITGA4_ITGB1+PLAUR&CD8A_CD8B+LCK  Ruxolitinib     Dasatinib
# 5  PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1    Sorafenib  Galunisertib
#
#            targets1          targets2
# 0       {FLT1, KDR}  {PDGFRA, PDGFRB}
# 1          {PDGFRB}          {PDGFRA}
# 2       {FLT1, KDR}  {PDGFRA, PDGFRB}
# 3           {PLAUR}  {PDGFRA, PDGFRB}
# 4           {PLAUR}             {LCK}
# 5  {PDGFRA, PDGFRB}           {TGFB1}

# %%
all_matrix_unfiltered = pd.read_csv('/home/lnemati/drug_synergies/processed_synergy_dataset_matrix_all_pairs_unfiltered.csv')
all_anchor_unfiltered = pd.read_csv('/home/lnemati/drug_synergies/processed_synergy_dataset_anchor_all_pairs_unfiltered.csv')

# Add targets to unfiltered datasets (same logic as before)

all_matrix_unfiltered['targets1'] = all_matrix_unfiltered['lib1_name'].apply(
    lambda x: merge_targets(x, drug_to_targets, drugbank_to_targets)
)
all_matrix_unfiltered['targets2'] = all_matrix_unfiltered['lib2_name'].apply(
    lambda x: merge_targets(x, drug_to_targets, drugbank_to_targets)
)

all_anchor_unfiltered['targets1'] = all_anchor_unfiltered['ANCHOR_NAME'].apply(
    lambda x: merge_targets(x, drug_to_targets, drugbank_to_targets)
)
all_anchor_unfiltered['targets2'] = all_anchor_unfiltered['LIBRARY_NAME'].apply(
    lambda x: merge_targets(x, drug_to_targets, drugbank_to_targets)
)

# %%
# --- Combine anchor and matrix datasets ---

df1 = all_anchor_unfiltered.rename(
    columns={
        'ANCHOR_NAME': 'drug1',
        'LIBRARY_NAME': 'drug2',
    }
)

df2 = all_matrix_unfiltered.rename(
    columns={
        'lib1_name': 'drug1',
        'lib2_name': 'drug2',
    }
)

all_synergies = pd.concat([
    df1[['drug1', 'targets1', 'drug2', 'targets2']],
    df2[['drug1', 'targets1', 'drug2', 'targets2']]
], ignore_index=True)

# Drop those without target
all_synergies = all_synergies.dropna()

# --- Filter targets to only genes appearing in cliques ---
all_clique_genes = set(all_clique_genes)

all_synergies["targets1"] = all_synergies["targets1"].apply(
    lambda x: [g for g in x if g in all_clique_genes]
)
all_synergies["targets2"] = all_synergies["targets2"].apply(
    lambda x: [g for g in x if g in all_clique_genes]
)

# --- Discard empty rows ---
all_synergies = all_synergies[
    (all_synergies["targets1"].str.len() > 0) &
    (all_synergies["targets2"].str.len() > 0)
]

# Remove exact duplicates
all_synergies = all_synergies[~all_synergies[['drug1','drug2']].duplicated()]

# --- Canonicalize unordered drug pairs ---
all_synergies['pair'] = all_synergies.apply(
    lambda x: tuple(sorted([x['drug1'], x['drug2']])),
    axis=1
)

all_synergies = all_synergies.drop_duplicates(subset='pair')
all_synergies = all_synergies.drop(columns='pair')

# %%
results = []

for _, syn in all_synergies.iterrows():

    targets1 = set(syn.targets1)
    targets2 = set(syn.targets2)
    
    for _, clique_row in tumor_cliques.iterrows():
        
        genes1 = set(clique_row.int1)
        genes2 = set(clique_row.int2)

        subset1 = targets1 & genes1
        subset2 = targets2 & genes2
        
        if subset1 == subset2:
            continue
        
        if subset1 and subset2:
            results.append({
                "Interaction": clique_row.Interaction,
                "drug1": syn.drug1,
                "drug2": syn.drug2,
                "targets1": subset1,
                "targets2": subset2,
            })

all_detectable_df = pd.DataFrame(results)

# %%
all_detectable_df
# Out:
#                              Interaction        drug1         drug2  \
# 0       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB     Axitinib     Sorafenib
# 1  ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB  Ruxolitinib     Sorafenib
# 2              PDGFB+PDGFRB&PDGFB+PDGFRA    Dasatinib     Sorafenib
# 3  PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1    Dasatinib  Galunisertib
#
#            targets1          targets2
# 0       {FLT1, KDR}  {PDGFRA, PDGFRB}
# 1           {PLAUR}  {PDGFRA, PDGFRB}
# 2          {PDGFRB}          {PDGFRA}
# 3  {PDGFRA, PDGFRB}           {TGFB1}

# %%
result_df
# Out:
#                              Interaction        drug1         drug2  \
# 0       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB     Axitinib     Sorafenib
# 1              PDGFB+PDGFRB&PDGFB+PDGFRA    Sorafenib     Dasatinib
# 2       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib     Dasatinib
# 3  ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB  Ruxolitinib     Dasatinib
# 4        ITGA4_ITGB1+PLAUR&CD8A_CD8B+LCK  Ruxolitinib     Dasatinib
# 5  PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1    Sorafenib  Galunisertib
#
#            targets1          targets2
# 0       {FLT1, KDR}  {PDGFRA, PDGFRB}
# 1          {PDGFRB}          {PDGFRA}
# 2       {FLT1, KDR}  {PDGFRA, PDGFRB}
# 3           {PLAUR}  {PDGFRA, PDGFRB}
# 4           {PLAUR}             {LCK}
# 5  {PDGFRA, PDGFRB}           {TGFB1}

# %%
# Make sure the targets are frozen sets for comparison
result_df['_pair_key'] = result_df.apply(lambda x: tuple(sorted([x['drug1'], x['drug2']])), axis=1)
all_detectable_df['_pair_key'] = all_detectable_df.apply(lambda x: tuple(sorted([x['drug1'], x['drug2']])), axis=1)

# Find pairs in all_detectable_df but missing in result_df
missing_pairs = set(all_detectable_df['_pair_key']) - set(result_df['_pair_key'])

# Extract the rows for inspection
missing_rows = all_detectable_df[all_detectable_df['_pair_key'].isin(missing_pairs)].copy()

# Join with result_df on the same pair key to compare targets
compare_df = missing_rows.merge(
    result_df[['targets1','targets2','_pair_key']],
    on='_pair_key',
    how='left',
    suffixes=('_all','_filtered')
)

# Check differences
compare_df['targets1_diff'] = compare_df.apply(lambda row: row['targets1_all'] != row['targets1_filtered'], axis=1)
compare_df['targets2_diff'] = compare_df.apply(lambda row: row['targets2_all'] != row['targets2_filtered'], axis=1)

# Show only rows where targets differ
target_diff = compare_df[(compare_df['targets1_diff']) | (compare_df['targets2_diff'])]
print(target_diff[['drug1','drug2','targets1_all','targets1_filtered','targets2_all','targets2_filtered']])
# Out:
#          drug1         drug2      targets1_all targets1_filtered  \
# 0  Ruxolitinib     Sorafenib           {PLAUR}               NaN
# 1    Dasatinib  Galunisertib  {PDGFRA, PDGFRB}               NaN
#
#        targets2_all targets2_filtered
# 0  {PDGFRA, PDGFRB}               NaN
# 1           {TGFB1}               NaN

# %%
result_df
# Out:
#                              Interaction        drug1         drug2  \
# 0       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB     Axitinib     Sorafenib
# 1              PDGFB+PDGFRB&PDGFB+PDGFRA    Sorafenib     Dasatinib
# 2       FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib     Dasatinib
# 3  ITGA4_ITGB1+PLAUR&PDGFB+PDGFRA_PDGFRB  Ruxolitinib     Dasatinib
# 4        ITGA4_ITGB1+PLAUR&CD8A_CD8B+LCK  Ruxolitinib     Dasatinib
# 5  PDGFB+PDGFRA_PDGFRB&ITGAV_ITGB6+TGFB1    Sorafenib  Galunisertib
#
#            targets1          targets2
# 0       {FLT1, KDR}  {PDGFRA, PDGFRB}
# 1          {PDGFRB}          {PDGFRA}
# 2       {FLT1, KDR}  {PDGFRA, PDGFRB}
# 3           {PLAUR}  {PDGFRA, PDGFRB}
# 4           {PLAUR}             {LCK}
# 5  {PDGFRA, PDGFRB}           {TGFB1}

# %%
matched_pairs

# %%
clique_drugs.loc['FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB']
# Out:
#                                         drug1  \
# clique
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB    Sorafenib
# ...                                       ...
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  Pralsetinib
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  Pralsetinib
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  Pralsetinib
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  Pralsetinib
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  Pralsetinib
#
#                                                                    targets1  \
# clique
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  ['EGFR', 'FLT4', 'KDR', 'FLT1', 'PDGFRB']
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  ['EGFR', 'FLT4', 'KDR', 'FLT1', 'PDGFRB']
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  ['EGFR', 'FLT4', 'KDR', 'FLT1', 'PDGFRB']
# FLT1_KDR+PGF&PDGFB+PDGFRA_PDGFRB  ['EGFR', 'FLT4', 'KDR', 'FLT1', 'PDGFRB']
# ...

# %%
pd.Series([('AZD6738', 'Olaparib')]).isin(pairs2)
# Out:
# 0    True
# dtype: bool

# %%
pd.Series([('Dasatinib', 'Sorafenib')]).isin(pairs2)
# Out:
# 0    False
# dtype: bool

# %%
clique_drugs
# Out:
#                                                                         drug1  \
# clique
# CD4+HLA-DQA2&CD4+HLA-DRB5               Antithymocyte immunoglobulin (rabbit)
# CD4+HLA-DQA2&CD4+HLA-DRB5                                          Ibalizumab
# CD4+HLA-DQA2&CD4+HLA-DRB1               Antithymocyte immunoglobulin (rabbit)
# CD4+HLA-DQA2&CD4+HLA-DRB1                                          Ibalizumab
# CD4+HLA-DQA1&CD4+HLA-DRB5               Antithymocyte immunoglobulin (rabbit)
# ...                                                                       ...
# COL12A1+ITGA11_ITGB1&CD80+CTLA4         Antithymocyte immunoglobulin (rabbit)
# COL10A1+ITGA10_ITGB1&TNFRSF11B+TNFSF11  Antithymocyte immunoglobulin (rabbit)
# COL10A1+ITGA10_ITGB1&TNFRSF11B+TNFSF11  Antithymocyte immunoglobulin (rabbit)
# CCL22+CCR4&TNFRSF11B+TNFSF11                                    Mogamulizumab
# CCL22+CCR4&TNFRSF11B+TNFSF11                                    Mogamulizumab
#
# ...

# %%
pairs1
# Out:
# clique
# CD4+HLA-DQA2&CD4+HLA-DRB5                 (Antithymocyte immunoglobulin (rabbit), Coccid...
# CD4+HLA-DQA2&CD4+HLA-DRB5                       (Coccidioides immitis spherule, Ibalizumab)
# CD4+HLA-DQA2&CD4+HLA-DRB1                 (Antithymocyte immunoglobulin (rabbit), Coccid...
# CD4+HLA-DQA2&CD4+HLA-DRB1                       (Coccidioides immitis spherule, Ibalizumab)
# CD4+HLA-DQA1&CD4+HLA-DRB5                 (Antithymocyte immunoglobulin (rabbit), Coccid...
#                                                                 ...
# COL12A1+ITGA11_ITGB1&CD80+CTLA4           (Antithymocyte immunoglobulin (rabbit), Tremel...
# COL10A1+ITGA10_ITGB1&TNFRSF11B+TNFSF11    (Antithymocyte immunoglobulin (rabbit), Lenali...
# COL10A1+ITGA10_ITGB1&TNFRSF11B+TNFSF11    (Antithymocyte immunoglobulin (rabbit), Denosu...
# CCL22+CCR4&TNFRSF11B+TNFSF11                                  (Lenalidomide, Mogamulizumab)
# ...

# %%
pairs1
# Out:
# clique
# CD4+HLA-DQA2&CD4+HLA-DRB5                 (Antithymocyte immunoglobulin (rabbit), Coccid...
# CD4+HLA-DQA2&CD4+HLA-DRB5                       (Coccidioides immitis spherule, Ibalizumab)
# CD4+HLA-DQA2&CD4+HLA-DRB1                 (Antithymocyte immunoglobulin (rabbit), Coccid...
# CD4+HLA-DQA2&CD4+HLA-DRB1                       (Coccidioides immitis spherule, Ibalizumab)
# CD4+HLA-DQA1&CD4+HLA-DRB5                 (Antithymocyte immunoglobulin (rabbit), Coccid...
#                                                                 ...
# COL12A1+ITGA11_ITGB1&CD80+CTLA4           (Antithymocyte immunoglobulin (rabbit), Tremel...
# COL10A1+ITGA10_ITGB1&TNFRSF11B+TNFSF11    (Antithymocyte immunoglobulin (rabbit), Lenali...
# COL10A1+ITGA10_ITGB1&TNFRSF11B+TNFSF11    (Antithymocyte immunoglobulin (rabbit), Denosu...
# CCL22+CCR4&TNFRSF11B+TNFSF11                                  (Lenalidomide, Mogamulizumab)
# ...

# %%
matched_pairs
# Out:
# Empty DataFrame
# Columns: [drug1, targets1, type1, drug2, targets2, type2]
# Index: []

# %%
drugs_df.query('drug == "Dasatinib"')

# %%
gdsc_drugs.query('DRUG_NAME == "Dasatinib"')

# %%
anchor = set(drugs_df.drug[drugs_df.drug.isin(synergies_anchor['ANCHOR_NAME'])])
library = set(drugs_df.drug[drugs_df.drug.isin(synergies_anchor['LIBRARY_NAME'])])
matrix1 = set(drugs_df.drug[drugs_df.drug.isin(synergies_matrix['lib1_name'])])
matrix1 = set(drugs_df.drug[drugs_df.drug.isin(synergies_matrix['lib2_name'])])

drugs_in_data = anchor | library | matrix1 | matrix2

# %%
all_clique_genes

# %%
tumor_cliques['int1']

# %%
drugs_in_data

# %%
mask1 = clique_drugs.drug1.isin(drugs_in_data)
mask2 = clique_drugs.drug2.isin(drugs_in_data)

# This are not the correct pairs, these are just the cases where both drugs are actually in
# both my data and the synergyes database, but I'm not checking that they match
clique_drugs[mask1 & mask2]

# %%
synergies_anchor

# %%
mask1 = synergies_anchor['ANCHOR_NAME'].str.lower().isin(clique_drugs.drug1.str.lower()) | synergies_anchor['ANCHOR_NAME'].str.lower().isin(clique_drugs.drug2.str.lower())
mask2 = synergies_anchor['LIBRARY_NAME'].str.lower().isin(clique_drugs.drug1.str.lower()) | synergies_anchor['LIBRARY_NAME'].str.lower().isin(clique_drugs.drug2.str.lower())

synergies_pairs = synergies_anchor.loc[mask1 & mask2]
synergies_pairs = synergies_pairs[['COMBI_ID', 'Tissue', 'CELL_LINE_NAME', 'ANCHOR_NAME', 'LIBRARY_NAME']]

synergies_pairs = [set(pair) for pair in zip(synergies_pairs.ANCHOR_NAME, synergies_pairs.LIBRARY_NAME)]
clique_drugs_pairs = [set(pair) for pair in zip(clique_drugs.drug1, clique_drugs.drug2)]

synergies_pairs_set = {frozenset(p) for p in synergies_pairs}
clique_drugs_pairs_set = {frozenset(p) for p in clique_drugs_pairs}

# Get synergies that are in our clique df
shared_pairs = synergies_pairs_set & clique_drugs_pairs_set

# Find corresponding cliques
clique_drugs["pair"] = clique_drugs.apply(
    lambda r: frozenset([r.drug1, r.drug2]), axis=1
)
cliques_targeted = clique_drugs[clique_drugs["pair"].isin(shared_pairs)]

# %%
cliques_targeted

# %%
shared_pairs

# %%
import re

def normalize(x):
    return (
        x.str.lower()
         .str.replace(r'[^a-z0-9]', '', regex=True)  # remove spaces, -, _, etc
    )

lib_norm = normalize(synergies_anchor['LIBRARY_NAME'])
drug_norm = normalize(drugs_exploded['drug'])

lib_norm.isin(drug_norm)

# %%
lib_norm

# %%
lib_norm.isin(drug_norm).sum()

# %%
drugs_exploded

# %%
synergies_anchor['LIBRARY_NAME'].str.lower.

# %%
synergies_anchor['LIBRARY_NAME']

# %%
pairs[['ANCHOR_NAME', 'LIBRARY_NAME']]

# %%
len(set(pairs['ANCHOR_NAME']).union(pairs['LIBRARY_NAME']))

# %%
pairs[['ANCHOR_NAME', 'LIBRARY_NAME']].nunique()

# %%
clique_drugs.drug1[clique_drugs.drug1.str.lower().str.startswith('AZD')]

# %%
clique_drugs

# %%
del tree

# %%
all_genes = set(tumor_cliques.all_genes.sum())

cliques_per_gene = {}

for gene in all_genes:
    cliques_per_gene[gene] = tumor_cliques.all_genes.apply(lambda x: gene in x).sum()
    
cliques_per_gene = pd.Series(cliques_per_gene).sort_values()[::-1]

# %%
cliques_per_gene.loc[['CD80', 'CD86', 'CTLA4', 'PDCD1', 'CD274', 'PDCD1LG2']]
# Out:
# CD80        293
# CD86        237
# CTLA4       239
# PDCD1       128
# CD274       109
# PDCD1LG2     75
# dtype: int64

# %%
tumor

# %%
cliques_per_gene.loc['ICOS']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cliques_per_gene.loc['ICOS']
#
# NameError: name 'cliques_per_gene' is not defined
